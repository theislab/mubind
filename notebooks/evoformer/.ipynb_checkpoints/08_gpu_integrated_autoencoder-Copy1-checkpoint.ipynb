# %%
# %load_ext autoreload
# %autoreload 2
import mubind as mb
import numpy as np
import pandas as pd
import torch
import torch.optim as topti
import torch.utils.data as tdata
import bindome as bd
bd.constants.ANNOTATIONS_DIRECTORY = '../annotations'
import matplotlib.pyplot as plt
import seaborn as sns
import logomaker
import os
import scipy
import pickle

# Use a GPU if available, as it should be faster.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using device: cuda:0

# %%
matlab_path = os.path.join(bd.constants.ANNOTATIONS_DIRECTORY, 'pbm', 'affreg', 'PbmDataHom6_norm.mat')
mat = scipy.io.loadmat(matlab_path)
data = mat['PbmData'][0]
seqs_dna =  data[0][5]
seqs_dna = [s[0][0] for s in seqs_dna]
# load the MSA sequences, one hot encoded
df, signal = bd.datasets.PBM.pbm_homeo_affreg()
# x, y = pickle.load(open('../../data/example_homeo_PbmData.pkl', 'rb'))

x, y = pickle.load(open('../../data/example_homeo_PbmData.pkl', 'rb'))
# x, y = pickle.load(open('../annotations/pbm/example_homeo_PbmData.pkl', 'rb'))

# %%
# reverse operation (recover aminoacids from one-hot encoded representation
prot_seq = []
for r in x:
    keys_aa = mb.tl.get_protein_aa_index()
    # r = r.T
    # print(r.shape)
    # r = r.cpu().detach().numpy()
    seq = ''.join(np.array(sorted(keys_aa))[np.argmax(r, axis=0)]) # , axis=1)\
    # print(r.shape, seq)
    prot_seq.append(seq)

# %%
# shift signal by adding a constant s.t. no negative values are included
signal -= np.min(signal)

# %%
# Set up the dataset
df = pd.DataFrame(signal.T)
df['seq'] = seqs_dna
df.index = df['seq']
del df['seq']

# %%
# df = df.head(1000)
df = df.reindex(df.var(axis=1).sort_values()[-500:].index)

# %%
df.shape
# Out:
# (500, 178)

# %%
dataset = mb.datasets.ResiduePBMDataset(df, x)
train = tdata.DataLoader(dataset=dataset, batch_size=128, shuffle=True)

# Set up the model
model = mb.models.ProteinDNABinding(0, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()    # mean-squared error for regression
reconstruction_crit = torch.nn.CrossEntropyLoss()

# %%
model = model.cuda()

# %%
mb.tl.train_network(model, train, device, optimizer, criterion, reconstruction_crit, num_epochs=50, exp_max=-1, log_each=1, verbose=2)
# Out:
# optimizing using <class 'torch.optim.adam.Adam'> and <class 'torch.nn.modules.loss.MSELoss'> n_epochs 50 early_stopping -1
# lr= 0.001, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 733329.154207 , best epoch: 0 secs per epoch: 16.515 s
# Epoch:  3, Loss: 1737807.775211 , best epoch: 0 secs per epoch: 13.298 s
# Epoch:  4, Loss: 2035050.210152 , best epoch: 0 secs per epoch: 11.816 s
# Epoch:  5, Loss: 2156617.353213 , best epoch: 0 secs per epoch: 11.048 s
# Epoch:  6, Loss: 1992213.950397 , best epoch: 0 secs per epoch: 10.530 s
# Epoch:  7, Loss: 3068654.713093 , best epoch: 0 secs per epoch: 10.144 s
# Epoch:  8, Loss: 2631022.149465 , best epoch: 0 secs per epoch: 9.878 s
# Epoch:  9, Loss: 1931312.768442 , best epoch: 0 secs per epoch: 9.719 s
# Epoch: 10, Loss: 2284846.072490 , best epoch: 0 secs per epoch: 9.580 s
# Epoch: 11, Loss: 1869337.672071 , best epoch: 0 secs per epoch: 9.472 s
# Epoch: 12, Loss: 2610204.514738 , best epoch: 0 secs per epoch: 9.345 s
# Epoch: 13, Loss: 3389960.127413 , best epoch: 0 secs per epoch: 9.241 s
# Epoch: 14, Loss: 5662593.671050 , best epoch: 0 secs per epoch: 9.164 s
# Epoch: 15, Loss: 13157054.328582 , best epoch: 0 secs per epoch: 9.082 s
# Epoch: 16, Loss: 20409999.489797 , best epoch: 0 secs per epoch: 8.989 s
# Epoch: 17, Loss: 37328315.917593 , best epoch: 0 secs per epoch: 8.946 s
# Epoch: 18, Loss: 50900697.394441 , best epoch: 0 secs per epoch: 8.939 s
# Epoch: 19, Loss: 120869514.456829 , best epoch: 0 secs per epoch: 8.898 s
# Epoch: 20, Loss: 194221610.767584 , best epoch: 0 secs per epoch: 8.861 s
# Epoch: 21, Loss: 323899896.861014 , best epoch: 0 secs per epoch: 8.861 s
# Epoch: 22, Loss: 586742256.716034 , best epoch: 0 secs per epoch: 8.854 s
# Epoch: 23, Loss: 2671730333.473487 , best epoch: 0 secs per epoch: 8.870 s
# Epoch: 24, Loss: 3959997941.849890 , best epoch: 0 secs per epoch: 8.840 s
# Epoch: 25, Loss: 3542443050.025817 , best epoch: 0 secs per epoch: 8.825 s
# Epoch: 26, Loss: 5110107578.294327 , best epoch: 0 secs per epoch: 8.805 s
# Epoch: 27, Loss: 15289096647.655308 , best epoch: 0 secs per epoch: 8.803 s
# Epoch: 28, Loss: 23589681801.826218 , best epoch: 0 secs per epoch: 8.797 s
# Epoch: 29, Loss: 36075350604.926811 , best epoch: 0 secs per epoch: 8.785 s
# Epoch: 30, Loss: 183897638596.198456 , best epoch: 0 secs per epoch: 8.845 s
# Epoch: 31, Loss: 204812837163.664520 , best epoch: 0 secs per epoch: 8.873 s
# Epoch: 32, Loss: 446753752339.340454 , best epoch: 0 secs per epoch: 9.017 s
# Epoch: 33, Loss: 1095181507326.844482 , best epoch: 0 secs per epoch: 9.013 s
# Epoch: 34, Loss: 1688881087292.419434 , best epoch: 0 secs per epoch: 9.083 s
# Epoch: 35, Loss: 3760136751783.521484 , best epoch: 0 secs per epoch: 9.109 s
# Epoch: 36, Loss: 1845252905119.837402 , best epoch: 0 secs per epoch: 9.090 s
# Epoch: 37, Loss: 4371032916892.678223 , best epoch: 0 secs per epoch: 9.100 s
# Epoch: 38, Loss: 7405831772969.006836 , best epoch: 0 secs per epoch: 9.141 s
# Epoch: 39, Loss: 8842975783577.742188 , best epoch: 0 secs per epoch: 9.173 s
# Epoch: 40, Loss: 13998578862257.400391 , best epoch: 0 secs per epoch: 9.170 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [512], in <cell line: 1>()
# ----> 1 mb.tl.train_network(model, train, device, optimizer, criterion, reconstruction_crit, num_epochs=50, exp_max=-1, log_each=1, verbose=2)
#
# File /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/multibind/multibind/tl/prediction.py:167, in train_network(model, train_dataloader, device, optimiser, criterion, reconstruction_crit, num_epochs, early_stopping, dirichlet_regularization, exp_max, log_each, verbose)
#     165     if exp_max >= 0:
#     166         loss += model.exp_barrier(exp_max)
# --> 167     loss.backward()  # Calculate gradients.
#     168     optimiser.step()
#     170 else:
#
# File ~/miniconda3/envs/multibind/lib/python3.10/site-packages/torch/_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/miniconda3/envs/multibind/lib/python3.10/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
plt.subplot(3, 1, 1)
plt.plot(model.loss_history, 'b')
plt.subplot(3, 1, 2)
plt.plot(model.crit_history, 'r')
plt.subplot(3, 1, 3)
plt.plot(model.rec_history, 'g')

# %%
model.load_state_dict(model.best_model_state)

# %%
bm_pred = model.get_predicted_bm(torch.tensor(np.stack(x), device=device)[[0, 20, 50, 100, 150]])
bm_pred = bm_pred.cpu().detach().numpy()
for i in range(0, 5): # bm_pred.shape[0]):
    weights = bm_pred[i]
    weights = pd.DataFrame(weights)
    weights.index = "A", "C", "G", "T"
    crp_logo = logomaker.Logo(weights.T, shade_below=0.5, fade_below=0.5)
    plt.show()
    # break

# %%
bm_pred = model.get_predicted_bm(torch.tensor(np.stack(x), device=device))
bm_pred = bm_pred.cpu().detach().numpy()
bm_df = bm_pred.reshape(-1, 60)
bm_df = pd.DataFrame(bm_df.T)
corr = bm_df.corr()
import seaborn as sns
sns.clustermap(corr, figsize=[5, 5])

# %% [markdown]
# ### Explore the reconstructred aminoacid representations

# %%
outputs = []
rec = []
for i, batch in enumerate(train):
    # print(i) # batch)
    # Get a batch and potentially send it to GPU memory.
    mononuc = batch["mononuc"].to(device)
    # print(i, mononuc.shape)
    b = batch["batch"].to(device) if "batch" in batch else None
    rounds = batch["rounds"].to(device) if "rounds" in batch else None
    countsum = batch["countsum"].to(device) if "countsum" in batch else None
    residues = batch["residues"].to(device) if "residues" in batch else None

    store_rev = False
    if residues is not None and store_rev:
        mononuc_rev = batch["mononuc_rev"].to(device)
        inputs = (mononuc, mononuc_rev, b, countsum, residues)
    elif residues is not None:
        inputs = (mononuc, b, countsum, residues)
    elif store_rev:
        mononuc_rev = batch["mononuc_rev"].to(device)
        inputs = (mononuc, mononuc_rev, b, countsum)
    else:
        inputs = (mononuc, b, countsum)
        
    # print(inputs[0].shape[0])
    loss = None
    y, reconstruction = model(inputs)  # Forward pass through the network.
    # print(y.shape)
    outputs.append(list(np.array(y.cpu().detach().numpy())))
    rec.append(np.array(reconstruction.cpu().detach().numpy()))
    # break

# %%
len(outputs), len(rec)

# %%
model(inputs)[1].shape

# %%
len(outputs), len(rec)

# %%
train.dataset.signal

# %%
len(outputs)

# %%
# reconstruction.shape
reconstruction = reconstruction.cpu().detach()

# %%
len(rec)

# %%
for r in reconstruction:
    print(r.shape)
    break

# %%
# reverse operation (recover aminoacids from one-hot encoded representation
# rec_seq = []
topi = {}
for i, r in enumerate(reconstruction):
    # print(i)
    if i % 10 == 0:
        print(i, len(reconstruction))
    keys_aa = mb.tl.get_protein_aa_index()
    r = r.T
    # print(r.shape)
    # r = r.cpu().detach().numpy()
    # seq = ''.join(np.array(sorted(keys_aa))[np.argmax(r, axis=0)]) # , axis=1)\
    # print(r.shape, seq)
    # rec_seq.append(seq)
    df = pd.DataFrame(r)
    
    # get the top i sequences per reconstruction
    n = 5
    for i in range(n):
        next_seq = ''
        if not i in topi:
            topi[i] = []
        next_seq = []
        for c in df:
            # print(c, df[c].nlargest(n).index)
            next_seq.append(df[c].nlargest(n).index[i])
        rec_seq = ''.join(np.array(sorted(keys_aa))[np.array(next_seq)])
        topi[i].append(rec_seq)

# %%
#reconstruction

# %%
real = pd.DataFrame([aa for aa in r] for r in prot_seq)
pred = pd.DataFrame([aa for aa in r] for r in topi[0])

# %%
equal = pd.DataFrame()
for c in pred:
    scores = [ai == bi for ai, bi in zip(pred[c], real[c])]
    # print(c, scores)
    equal[c] = np.array(scores, dtype=int)

# %%
from matplotlib import rcParams
# rcParams['figure.figsize'] = 10, 2
mb.pl.alignment_protein(prot_seq[:20], figsize=[10, 6])
mb.pl.alignment_protein(topi[0][:20], figsize=[10, 6])

# %%
max_score = real.shape[0] * real.shape[1]

final_score = 0
res = []
for k in topi.keys():
    pred = pd.DataFrame([aa for aa in r] for r in topi[k])
    equal = pd.DataFrame()
    # print(pred.head())
    for c in pred:
        scores = [ai == bi for ai, bi in zip(pred[c], real[c])]
        # print(c, scores)
        equal[c] = np.array(scores, dtype=int)
        
    next_score = sum(equal.values.flatten())
    # print(k, next_score, max_score)
    final_score += next_score
    res.append([k, final_score, max_score])
    # print()
res = pd.DataFrame(res, columns=['n.top', 'final.score', 'max.score'])
res['frac.max'] = res['final.score'] / res['max.score']

rcParams['figure.figsize'] = 8, 8
sns.lineplot(data=res, x='n.top', y='frac.max', color='red', lw=3.0)
plt.xticks(list(topi.keys()));
plt.axhline(y=1.0, ls='--', c='gray')
plt.axhline(y=1.0, ls='--', c='gray')

# %%
# sns.heatmap(equal)
