# %% [markdown]
# ### Any modification to the code will be tested by
# - Changing the java files
# - Recompiling and checking the output files that are printed

# %% [markdown]
# cd to NRLB dir

# %%
cd ../../NRLB/ModelFitting
# Out:
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/multibind/NRLB/ModelFitting

# %%
# !./build.sh
# Out:
# mkdir: cannot create directory ‘tempdir’: File exists

# %%
# run the MAX case
# Recount kmersa and execute

# %%
# modify line 151 of src/Minimizers/LBFGS.java

# %%
# !./runNRLB.sh DataConfig.txt NRLBConfig.txt
# Out:
# Counting Kmers...
# Counting complete. Constructing Round0 Model...
# Round0 Model Construction Complete. Starting NRLB...
# 11:40:06.389:ArraysMergerHeap$MinHeapNode.<init>():70#main	Data file path:/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/multibind/NRLB/ModelFitting/tmp//MAX.1.R1.1.16.dat
# Finished reading data.
# Testing flank length 0
# Fitting NRLB model for length 8
# Fitting full dataset.
# Starting Function Value: 22.070810368983462
# Iterations   Fnc. Calls           Likelihood       Distance Moved           Step Alpha        Gradient Norm
#          1            3   22.068999104203453    0.157447401128324    6.597046418685064    0.018693941913714
#          2            4   22.067913233835030    0.090249709584805    1.000000000000000    0.011265838598739
#          3            5   22.067036595872178    0.176592316012399    1.000000000000000    0.006980817983550
# ...
