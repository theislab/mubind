# %%
import os
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/workspace/theislab/mubind/notebooks/batch
# Out:
# /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/notebooks/batch

# %%
import mubind as mb
import numpy as np
import pandas as pd
import torch
import bindome as bd
bd.constants.ANNOTATIONS_DIRECTORY = '../../annotations' # '../../annotations'
# mb.models.MultiBind
import torch.optim as topti
import torch.utils.data as tdata
import numpy as np

# %%
df = mb.bindome.datasets.ProBound.ctcf(flank_length=0)
df = df.sort_values(1, ascending=False).reset_index(drop=True)
# data = df.head(1000)
# data = df.copy()

df.index = df['seq']
del df['seq']
df.index = df.index.astype(str).str[45:]

df = df[~df.index.duplicated(keep='first')]

n_sample = 5000
data = df.sample(min(df.shape[0], n_sample))

# data = mb.pp.sample_rounds(df, 2, 10000)

# remove as many nucleotides as posisble (faster training/convergence)


# data.index = data.index.astype(str).str[-15:]

# %%
df
# Out:
#                            0  1
# seq
# CATGTAGACCGGCCATTGGACTATG  0  4
# GCGTTGATGGTATCGTAAGTGCGTC  0  4
# AGTGGCTGCTTGTCGGAATGGGCAG  0  4
# GGCGTTACGCGTTGTGTAGACCTAA  0  4
# CTCAGGTGGAATCTTTTTACTATTG  0  4
# ...                       .. ..
# AGAGAGACAGGACTTGTGACTTTGT  1  0
# AGAGGGCGTTCGAGGCTTGCTAGGC  1  0
# GGAGTGCCTTTTGGATGAAAGATTG  1  0
# GCTTGAGTAACCAAGGATTGCGTGG  1  0
# TAAAGCGCTTTAGCATTAAAACGTT  1  0
#
# [120053 rows x 2 columns]

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 5, 1

# %%
# TODO: skipped for now
n_rounds = 2

print('loading object (# entries)', data.shape[0])
dataset = mb.datasets.SelexDataset(data, n_rounds=n_rounds, labels=[0, 1])
train = tdata.DataLoader(dataset=dataset,
                         # batch_size=256,
                         batch_size=625,
                         shuffle=False)
# Out:
# loading object (# entries) 5000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %lprun -f mb.tl.train_network mb.tl.train_network(model, train, device, next_optimiser, criterion, num_epochs=20, early_stopping=100, log_each=2, dirichlet_regularization=0, exp_max=40, verbose=0)

# %%
# %lprun -f mb.tl.train_iterative mb.tl.train_iterative(train, device, w=18, show_logo=False, opt_kernel_shift=0, opt_kernel_length=0, dirichlet_regularization=dirichlet_regularization, lr=[0.01, 0.01], weight_decay=[0.01, 0.001], ignore_kernel=ignore_kernel, num_epochs=2, early_stopping=100, use_dinuc=False, n_kernels=n_kernels, log_each=log_each, stop_at_kernel=None)

# %%
pd.set_option('display.expand_frame_repr', False)

# %%
# assign batch and data type

# data['batch'] = 0
# data['is_count_data'] = 1
# n_batches=3

dirichlet_regularization = 0
# for dirichlet_regularization_log in range(-5, 3):

n_epochs = 100
log_each = 10
n_kernels = 2
lr = [0.01] * n_kernels
kernels = [0, 2] + [20] * (n_kernels - 1)
wd = [0.01,] + [0.001] * (n_kernels - 1)
early_stopping = [5,] + [10] * (n_kernels)

opt_kernel_shift = [0, 0] + [1] * (n_kernels - 1)
opt_kernel_length = [0, 0] + [1] * (n_kernels - 1)
use_mono = True
use_dinuc = True
dinuc_mode = 'local'

from matplotlib import rcParams
rcParams['figure.figsize'] = 8, 1

import time

criterion = mb.tl.PoissonLoss()

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
import itertools

# Use a GPU if available, as it should be faster.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))


optimize_exp_barrier, optimize_kernel_rel, optimize_sym_weight = True, True, True
total_time = []
for use_cpu in [True, False]:

    t0 = time.time()

    print(optimize_exp_barrier, optimize_kernel_rel, optimize_sym_weight)
    model = mb.models.Multibind.make_model(train, n_kernels, criterion, kernels=kernels,
                                           device=device if not use_cpu else 'cpu',
                                           use_dinuc=use_dinuc, dinuc_mode=dinuc_mode,
                                           optimize_exp_barrier= optimize_exp_barrier,
                                           optimize_kernel_rel = optimize_kernel_rel,
                                           optimize_sym_weight = optimize_sym_weight) # .cuda()

    print(model.device)


    model, best_loss = model.optimize_iterative(train,
                                                show_logo=0,
                                                r2_per_epoch=True,
                                                opt_kernel_length=opt_kernel_length,
                                                opt_kernel_shift=opt_kernel_shift,
                                                dirichlet_regularization=dirichlet_regularization, # 10 ** dirichlet_regularization_log,
                                                # lr=lr, weight_decay=wd, ignore_kernel=ignore_kernel,
                                                # skip_kernels={2, 3},
                                                n_epochs=n_epochs,
                                                early_stopping=early_stopping, # optimiser=torch.optim.LBFGS,
                                                log_each=log_each,
                                                stop_at_kernel=None) #  seed=seed) # seeds.index[0]) #
    print('##DONE....\n\n')



    print('total time: %.3f s' % ((time.time() - t0)))
    # res = []
    # model_by_k = {}

    # counts = mb.tl.predict(model, train)
    # print(counts)
    #
    # mb.pl.set_rcParams({'figure.figsize': [10, 6], 'figure.dpi': 65})
    # mb.pl.conv(model)
    #
    # mb.tl.scores(model, train, by='batch')
    # mb.pl.set_rcParams({'figure.figsize': [6, 6], 'figure.dpi': 85})
    # mb.pl.kmer_enrichment(model, train, log_scale=False, style='scatter', ylab='t1', xlab='p1')
    # mb.pl.activities(model)
    #
    # mb.pl.set_rcParams({'figure.figsize': [8, 4], 'figure.dpi': 85})
    # mb.pl.loss(model)

    total_time.append(model.total_time)
    # models.append([model, best_loss])
    # break
# Out:
# Using device: cuda:0
# True True True
# cpu
# current kernels
#
# Kernel to optimize 0
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (1, 0)
# setting grad status of kernel (mono, dinuc) at 1 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 2 to (0, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 5
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 132.219751, R2: -1.10,  best epoch: 9,  secs per epoch: 0.424 s,  secs epoch*1k trials: 0.085s
# Epoch: 21, Loss: 131.763746, R2: -0.94,  best epoch: 19,  secs per epoch: 0.369 s,  secs epoch*1k trials: 0.074s
# Epoch: 31, Loss: 131.402328, R2: -0.50,  best epoch: 29,  secs per epoch: 0.352 s,  secs epoch*1k trials: 0.070s
# Epoch: 41, Loss: 131.226582, R2: -0.08,  best epoch: 39,  secs per epoch: 0.378 s,  secs epoch*1k trials: 0.076s
# Epoch: 51, Loss: 131.182749, R2: 0.03,  best epoch: 49,  secs per epoch: 0.378 s,  secs epoch*1k trials: 0.076s
# Epoch: 61, Loss: 131.175671, R2: 0.04,  best epoch: 59,  secs per epoch: 0.404 s,  secs epoch*1k trials: 0.081s
# Epoch: 71, Loss: 131.174700, R2: 0.04,  best epoch: 69,  secs per epoch: 0.398 s,  secs epoch*1k trials: 0.080s
# Epoch: 81, Loss: 131.174557, R2: 0.04,  best epoch: 79,  secs per epoch: 0.424 s,  secs epoch*1k trials: 0.085s
# Epoch: 91, Loss: 131.174534, R2: 0.04,  best epoch: 89,  secs per epoch: 0.419 s,  secs epoch*1k trials: 0.084s
# Final loss: 131.1745243073 , R2: 0.04
# Total time (model/function): (41.733s / 41.733s)
# Time per epoch (model/function): (0.422s/ 0.422s)
# Time per epoch per 1k trials: 0.084s
# Current time: 2023-01-28 23:30:55.431135
# optimization of dinuc is not necessary for the intercepts (kernel=0). Skip...
# current kernels
#
# Kernel to optimize 1
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 1 to (1, 0)
# setting grad status of kernel (mono, dinuc) at 2 to (0, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 130.598846, R2: 0.04,  best epoch: 6,  secs per epoch: 0.937 s,  secs epoch*1k trials: 0.187s
# Epoch: 21, Loss: 130.595253, R2: 0.04,  best epoch: 11,  secs per epoch: 0.745 s,  secs epoch*1k trials: 0.149s
# Epoch: 22, Loss: 130.599125, R2: 0.04,  best epoch: 11,  secs per epoch: 0.764s,  secs epoch*1k trials: 0.153s
# early stop!
# Final loss: 130.5991249084 , R2: 0.04
# Total time (model/function): (57.786s / 16.053s)
# Time per epoch (model/function): (2.752s/ 0.764s)
# Time per epoch per 1k trials: 0.153s
# Current time: 2023-01-28 23:31:11.863475
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
# kernel grad (0) = 1
# kernel grad (1) = 1
# kernel grad (2) = 1
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 1.437043, R2: 0.04,  best epoch: 9,  secs per epoch: 0.482 s,  secs epoch*1k trials: 0.096s
# Epoch: 21, Loss: 1.437032, R2: 0.04,  best epoch: 19,  secs per epoch: 0.537 s,  secs epoch*1k trials: 0.107s
# Epoch: 31, Loss: 1.437030, R2: 0.04,  best epoch: 29,  secs per epoch: 0.549 s,  secs epoch*1k trials: 0.110s
# Epoch: 41, Loss: 1.437028, R2: 0.04,  best epoch: 39,  secs per epoch: 0.637 s,  secs epoch*1k trials: 0.127s
# Epoch: 51, Loss: 1.437025, R2: 0.04,  best epoch: 49,  secs per epoch: 0.681 s,  secs epoch*1k trials: 0.136s
# Epoch: 61, Loss: 1.437023, R2: 0.04,  best epoch: 59,  secs per epoch: 0.676 s,  secs epoch*1k trials: 0.135s
# Epoch: 71, Loss: 1.437020, R2: 0.04,  best epoch: 69,  secs per epoch: 0.709 s,  secs epoch*1k trials: 0.142s
# Epoch: 81, Loss: 1.437017, R2: 0.04,  best epoch: 79,  secs per epoch: 0.710 s,  secs epoch*1k trials: 0.142s
# Epoch: 91, Loss: 1.437015, R2: 0.04,  best epoch: 89,  secs per epoch: 0.707 s,  secs epoch*1k trials: 0.141s
# Final loss: 1.4370137155 , R2: 0.04
# Total time (model/function): (125.818s / 68.033s)
# Time per epoch (model/function): (1.271s/ 0.687s)
# Time per epoch per 1k trials: 0.137s
# Current time: 2023-01-28 23:32:20.108254
# best loss 1.4370137155056
# current r2 values by newly added kernel
# [0.038582315949198254]
# optimizing feature type dinuc
# setting grad status of kernel (mono, dinuc) at 0 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 1 to (0, 1)
# setting grad status of kernel (mono, dinuc) at 2 to (0, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 128.905962, R2: 0.04,  best epoch: 7,  secs per epoch: 0.422 s,  secs epoch*1k trials: 0.084s
# Epoch: 18, Loss: 128.906069, R2: 0.04,  best epoch: 7,  secs per epoch: 0.409s,  secs epoch*1k trials: 0.082s
# early stop!
# Final loss: 128.9060688019 , R2: 0.04
# Total time (model/function): (132.766s / 6.948s)
# Time per epoch (model/function): (7.810s/ 0.409s)
# Time per epoch per 1k trials: 0.082s
# Current time: 2023-01-28 23:32:27.664571
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
# kernel grad (0) = 1
# kernel grad (1) = 1
# kernel grad (2) = 1
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 1.437006, R2: 0.04,  best epoch: 9,  secs per epoch: 0.612 s,  secs epoch*1k trials: 0.122s
# Epoch: 21, Loss: 1.437005, R2: 0.04,  best epoch: 13,  secs per epoch: 0.692 s,  secs epoch*1k trials: 0.138s
# Epoch: 31, Loss: 1.437003, R2: 0.04,  best epoch: 29,  secs per epoch: 0.598 s,  secs epoch*1k trials: 0.120s
# Epoch: 41, Loss: 1.437002, R2: 0.04,  best epoch: 39,  secs per epoch: 0.580 s,  secs epoch*1k trials: 0.116s
# Epoch: 51, Loss: 1.437001, R2: 0.04,  best epoch: 49,  secs per epoch: 0.555 s,  secs epoch*1k trials: 0.111s
# Epoch: 61, Loss: 1.436999, R2: 0.04,  best epoch: 59,  secs per epoch: 0.532 s,  secs epoch*1k trials: 0.106s
# Epoch: 71, Loss: 1.436998, R2: 0.04,  best epoch: 69,  secs per epoch: 0.514 s,  secs epoch*1k trials: 0.103s
# Epoch: 81, Loss: 1.436996, R2: 0.04,  best epoch: 79,  secs per epoch: 0.509 s,  secs epoch*1k trials: 0.102s
# Epoch: 91, Loss: 1.436995, R2: 0.04,  best epoch: 89,  secs per epoch: 0.487 s,  secs epoch*1k trials: 0.097s
# Final loss: 1.4369939864 , R2: 0.04
# Total time (model/function): (179.321s / 46.554s)
# Time per epoch (model/function): (1.811s/ 0.470s)
# Time per epoch per 1k trials: 0.094s
# Current time: 2023-01-28 23:33:14.394074
# best loss 1.4369939863681793
# current r2 values by newly added kernel
# [0.038582315949198254, 0.03862052773918423]
# current kernels
#
# Kernel to optimize 2
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 1 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 2 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 121.564642, R2: 0.04,  best epoch: 5,  secs per epoch: 0.277 s,  secs epoch*1k trials: 0.055s
# Epoch: 16, Loss: 121.601103, R2: 0.04,  best epoch: 5,  secs per epoch: 0.310s,  secs epoch*1k trials: 0.062s
# early stop!
# Final loss: 121.6011028290 , R2: 0.04
# Total time (model/function): (183.977s / 4.656s)
# Time per epoch (model/function): (12.265s/ 0.310s)
# Time per epoch per 1k trials: 0.062s
# Current time: 2023-01-28 23:33:19.486387
#
# WIDTH OPTIMIZATION (first)...
# Reached maximum w. Stop...
#
# SHIFT OPTIMIZATION (first)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.997647, R2: 0.04,  best epoch: 9,  secs per epoch: 0.253s,  secs epoch*1k trials: 0.051s
# early stop!
# Final loss: 120.9976472855 , R2: 0.04
# Total time (model/function): (188.793s / 4.817s)
# Time per epoch (model/function): (9.936s/ 0.254s)
# Time per epoch per 1k trials: 0.051s
# Current time: 2023-01-28 23:33:24.680013
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 121.491666, R2: 0.04,  best epoch: 8,  secs per epoch: 0.255s,  secs epoch*1k trials: 0.051s
# early stop!
# Final loss: 121.4916658401 , R2: 0.04
# Total time (model/function): (188.563s / 4.587s)
# Time per epoch (model/function): (10.476s/ 0.255s)
# Time per epoch per 1k trials: 0.051s
# Current time: 2023-01-28 23:33:29.651016
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 121.717887, R2: 0.04,  best epoch: 8,  secs per epoch: 0.276s,  secs epoch*1k trials: 0.055s
# early stop!
# Final loss: 121.7178869247 , R2: 0.04
# Total time (model/function): (188.947s / 4.970s)
# Time per epoch (model/function): (10.497s/ 0.276s)
# Time per epoch per 1k trials: 0.055s
# Current time: 2023-01-28 23:33:35.149669
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 121.424097, R2: 0.04,  best epoch: 8,  secs per epoch: 0.270s,  secs epoch*1k trials: 0.054s
# early stop!
# Final loss: 121.4240970612 , R2: 0.04
# Total time (model/function): (188.840s / 4.864s)
# Time per epoch (model/function): (10.491s/ 0.270s)
# Time per epoch per 1k trials: 0.054s
# Current time: 2023-01-28 23:33:40.474424
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 120.827972, R2: 0.04,  best epoch: 8,  secs per epoch: 0.345s,  secs epoch*1k trials: 0.069s
# early stop!
# Final loss: 120.8279724121 , R2: 0.04
# Total time (model/function): (190.195s / 6.218s)
# Time per epoch (model/function): (10.566s/ 0.345s)
# Time per epoch per 1k trials: 0.069s
# Current time: 2023-01-28 23:33:47.066320
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 1            0             0      2   0.319358     20       0.601675  120.827048  0.038387  121.558434
# 2            0             0     -2   0.316221     20       0.462058  120.996764  0.038461  121.558434
# 3            0             0      1   0.345436     20       0.111380  121.423043  0.038463  121.558434
# 4            0             0     -1   0.333670     20       0.055780  121.490629  0.038476  121.558434
# 0            0             0      0   0.319358     20       0.000000  121.558434  0.038221  121.558434
# 5            0             0      0   0.359603     20      -0.130183  121.716683  0.038482  121.558434
# 0 0 2 0.31935811042785645 20 0.6016745672833388 120.82704830169678 0.038386991362459266
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.827979, R2: 0.04,  best epoch: 9,  secs per epoch: 0.354s,  secs epoch*1k trials: 0.071s
# early stop!
# Final loss: 120.8279790878 , R2: 0.04
# Total time (model/function): (196.919s / 6.723s)
# Time per epoch (model/function): (10.364s/ 0.354s)
# Time per epoch per 1k trials: 0.071s
# Current time: 2023-01-28 23:33:54.378428
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.827939, R2: 0.04,  best epoch: 9,  secs per epoch: 0.514s,  secs epoch*1k trials: 0.103s
# early stop!
# Final loss: 120.8279390335 , R2: 0.04
# Total time (model/function): (199.964s / 9.769s)
# Time per epoch (model/function): (10.524s/ 0.514s)
# Time per epoch per 1k trials: 0.103s
# Current time: 2023-01-28 23:34:04.719243
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.827897, R2: 0.04,  best epoch: 9,  secs per epoch: 0.373s,  secs epoch*1k trials: 0.075s
# early stop!
# Final loss: 120.8278970718 , R2: 0.04
# Total time (model/function): (197.274s / 7.079s)
# Time per epoch (model/function): (10.383s/ 0.373s)
# Time per epoch per 1k trials: 0.075s
# Current time: 2023-01-28 23:34:12.684918
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.474645, R2: 0.04,  best epoch: 9,  secs per epoch: 0.357s,  secs epoch*1k trials: 0.071s
# early stop!
# Final loss: 120.4746446609 , R2: 0.04
# Total time (model/function): (196.976s / 6.781s)
# Time per epoch (model/function): (10.367s/ 0.357s)
# Time per epoch per 1k trials: 0.071s
# Current time: 2023-01-28 23:34:20.046377
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.016541, R2: 0.04,  best epoch: 9,  secs per epoch: 0.336s,  secs epoch*1k trials: 0.067s
# early stop!
# Final loss: 120.0165405273 , R2: 0.04
# Total time (model/function): (196.578s / 6.383s)
# Time per epoch (model/function): (10.346s/ 0.336s)
# Time per epoch per 1k trials: 0.067s
# Current time: 2023-01-28 23:34:26.966938
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 2            0             0      2   0.329272     20       0.671373  120.015848  0.038528  120.827048
# 4            0             0      1   0.334757     20       0.292300  120.473870  0.038588  120.827048
# 5            0             0      0   0.350548     20       0.000011  120.827035  0.038613  120.827048
# 0            0             0      0   0.329272     20       0.000000  120.827048  0.038387  120.827048
# 3            0             0     -1   0.345328     20      -0.000082  120.827147  0.038563  120.827048
# 1            0             0     -2   0.340107     20      -0.000172  120.827256  0.038512  120.827048
# 0 0 2 0.3292717933654785 20 0.6713729693050414 120.01584815979004 0.03852774979914764
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.016540, R2: 0.04,  best epoch: 9,  secs per epoch: 0.337s,  secs epoch*1k trials: 0.067s
# early stop!
# Final loss: 120.0165395737 , R2: 0.04
# Total time (model/function): (202.974s / 6.396s)
# Time per epoch (model/function): (10.683s/ 0.337s)
# Time per epoch per 1k trials: 0.067s
# Current time: 2023-01-28 23:34:34.104616
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.016489, R2: 0.04,  best epoch: 9,  secs per epoch: 0.394s,  secs epoch*1k trials: 0.079s
# early stop!
# Final loss: 120.0164890289 , R2: 0.04
# Total time (model/function): (204.070s / 7.492s)
# Time per epoch (model/function): (10.741s/ 0.394s)
# Time per epoch per 1k trials: 0.079s
# Current time: 2023-01-28 23:34:42.045806
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 120.016453, R2: 0.04,  best epoch: 9,  secs per epoch: 0.354s,  secs epoch*1k trials: 0.071s
# early stop!
# Final loss: 120.0164527893 , R2: 0.04
# Total time (model/function): (203.305s / 6.727s)
# Time per epoch (model/function): (10.700s/ 0.354s)
# Time per epoch per 1k trials: 0.071s
# Current time: 2023-01-28 23:34:49.178873
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.707572, R2: 0.04,  best epoch: 9,  secs per epoch: 0.413s,  secs epoch*1k trials: 0.083s
# early stop!
# Final loss: 119.7075719833 , R2: 0.04
# Total time (model/function): (204.420s / 7.842s)
# Time per epoch (model/function): (10.759s/ 0.413s)
# Time per epoch per 1k trials: 0.083s
# Current time: 2023-01-28 23:34:57.550950
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.415473, R2: 0.04,  best epoch: 9,  secs per epoch: 0.325s,  secs epoch*1k trials: 0.065s
# early stop!
# Final loss: 119.4154729843 , R2: 0.04
# Total time (model/function): (202.748s / 6.170s)
# Time per epoch (model/function): (10.671s/ 0.325s)
# Time per epoch per 1k trials: 0.065s
# Current time: 2023-01-28 23:35:04.068608
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 2            0             0      2   0.277895     20       0.500823  119.414781  0.038460  120.015848
# 3            0             0      1   0.288159     20       0.257507  119.706799  0.038496  120.015848
# 4            0             0      0   0.309155     20       0.000214  120.015592  0.038498  120.015848
# 1            0             0     -1   0.303934     20       0.000123  120.015700  0.038448  120.015848
# 0            0             0     -2   0.298713     20       0.000030  120.015812  0.038398  120.015848
# 5            0             0      0   0.277895     20       0.000000  120.015848  0.038528  120.015848
# 0 0 2 0.277894526720047 20 0.5008234764374777 119.41478061676025 0.03846025983311885
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.415471, R2: 0.04,  best epoch: 9,  secs per epoch: 0.458s,  secs epoch*1k trials: 0.092s
# early stop!
# Final loss: 119.4154710770 , R2: 0.04
# Total time (model/function): (211.454s / 8.706s)
# Time per epoch (model/function): (11.129s/ 0.458s)
# Time per epoch per 1k trials: 0.092s
# Current time: 2023-01-28 23:35:14.318332
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.415423, R2: 0.04,  best epoch: 9,  secs per epoch: 0.300s,  secs epoch*1k trials: 0.060s
# early stop!
# Final loss: 119.4154233932 , R2: 0.04
# Total time (model/function): (208.440s / 5.692s)
# Time per epoch (model/function): (10.971s/ 0.300s)
# Time per epoch per 1k trials: 0.060s
# Current time: 2023-01-28 23:35:20.703457
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.415376, R2: 0.04,  best epoch: 9,  secs per epoch: 0.262s,  secs epoch*1k trials: 0.052s
# early stop!
# Final loss: 119.4153757095 , R2: 0.04
# Total time (model/function): (207.731s / 4.983s)
# Time per epoch (model/function): (10.933s/ 0.262s)
# Time per epoch per 1k trials: 0.052s
# Current time: 2023-01-28 23:35:26.057881
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.352409, R2: 0.04,  best epoch: 9,  secs per epoch: 0.250s,  secs epoch*1k trials: 0.050s
# early stop!
# Final loss: 119.3524093628 , R2: 0.04
# Total time (model/function): (207.497s / 4.749s)
# Time per epoch (model/function): (10.921s/ 0.250s)
# Time per epoch per 1k trials: 0.050s
# Current time: 2023-01-28 23:35:31.705586
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.276891, R2: 0.04,  best epoch: 9,  secs per epoch: 0.242s,  secs epoch*1k trials: 0.048s
# early stop!
# Final loss: 119.2768907547 , R2: 0.04
# Total time (model/function): (207.342s / 4.594s)
# Time per epoch (model/function): (10.913s/ 0.242s)
# Time per epoch per 1k trials: 0.048s
# Current time: 2023-01-28 23:35:36.726246
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 3            0             0      2   0.258213     20       0.116054  119.276196  0.038534  119.414781
# 4            0             0      1   0.276329     20       0.052880  119.351634  0.038561  119.414781
# 5            0             0      0   0.297274     20       0.000222  119.414515  0.038572  119.414781
# 2            0             0     -1   0.292053     20       0.000126  119.414630  0.038524  119.414781
# 1            0             0     -2   0.286832     20       0.000030  119.414744  0.038474  119.414781
# 0            0             0      0   0.258213     20       0.000000  119.414781  0.038460  119.414781
# 0 0 2 0.25821271538734436 20 0.11605354874952235 119.27619552612305 0.038534286290131003
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.276896, R2: 0.04,  best epoch: 9,  secs per epoch: 0.357s,  secs epoch*1k trials: 0.071s
# early stop!
# Final loss: 119.2768964767 , R2: 0.04
# Total time (model/function): (214.117s / 6.775s)
# Time per epoch (model/function): (11.269s/ 0.357s)
# Time per epoch per 1k trials: 0.071s
# Current time: 2023-01-28 23:35:44.146055
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.276847, R2: 0.04,  best epoch: 9,  secs per epoch: 0.337s,  secs epoch*1k trials: 0.067s
# early stop!
# Final loss: 119.2768468857 , R2: 0.04
# Total time (model/function): (213.756s / 6.414s)
# Time per epoch (model/function): (11.250s/ 0.338s)
# Time per epoch per 1k trials: 0.068s
# Current time: 2023-01-28 23:35:51.041970
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 119.276800, R2: 0.04,  best epoch: 9,  secs per epoch: 0.414s,  secs epoch*1k trials: 0.083s
# early stop!
# Final loss: 119.2768001556 , R2: 0.04
# Total time (model/function): (215.213s / 7.871s)
# Time per epoch (model/function): (11.327s/ 0.414s)
# Time per epoch per 1k trials: 0.083s
# Current time: 2023-01-28 23:35:59.317374
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.900857, R2: 0.04,  best epoch: 9,  secs per epoch: 0.281s,  secs epoch*1k trials: 0.056s
# early stop!
# Final loss: 118.9008569717 , R2: 0.04
# Total time (model/function): (212.688s / 5.346s)
# Time per epoch (model/function): (11.194s/ 0.281s)
# Time per epoch per 1k trials: 0.056s
# Current time: 2023-01-28 23:36:05.166297
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.861230, R2: 0.04,  best epoch: 9,  secs per epoch: 0.264s,  secs epoch*1k trials: 0.053s
# early stop!
# Final loss: 118.8612298965 , R2: 0.04
# Total time (model/function): (212.357s / 5.015s)
# Time per epoch (model/function): (11.177s/ 0.264s)
# Time per epoch per 1k trials: 0.053s
# Current time: 2023-01-28 23:36:10.546994
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 1            0             0      2   0.205199     20       0.348481  118.860540  0.038432  119.276196
# 3            0             0      1   0.225863     20       0.315333  118.900079  0.038486  119.276196
# 4            0             0      0   0.243380     20       0.000214  119.275940  0.038491  119.276196
# 2            0             0     -1   0.238159     20       0.000117  119.276056  0.038442  119.276196
# 0            0             0     -2   0.232938     20       0.000022  119.276170  0.038392  119.276196
# 5            0             0      0   0.205199     20       0.000000  119.276196  0.038534  119.276196
# 0 0 2 0.20519891381263733 20 0.3484812156146987 118.86054039001465 0.03843214958282459
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.861229, R2: 0.04,  best epoch: 9,  secs per epoch: 0.244s,  secs epoch*1k trials: 0.049s
# early stop!
# Final loss: 118.8612289429 , R2: 0.04
# Total time (model/function): (216.996s / 4.639s)
# Time per epoch (model/function): (11.421s/ 0.244s)
# Time per epoch per 1k trials: 0.049s
# Current time: 2023-01-28 23:36:15.732005
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.861178, R2: 0.04,  best epoch: 9,  secs per epoch: 0.273s,  secs epoch*1k trials: 0.055s
# early stop!
# Final loss: 118.8611783981 , R2: 0.04
# Total time (model/function): (217.536s / 5.179s)
# Time per epoch (model/function): (11.449s/ 0.273s)
# Time per epoch per 1k trials: 0.055s
# Current time: 2023-01-28 23:36:21.301735
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.861135, R2: 0.04,  best epoch: 9,  secs per epoch: 0.259s,  secs epoch*1k trials: 0.052s
# early stop!
# Final loss: 118.8611354828 , R2: 0.04
# Total time (model/function): (217.283s / 4.926s)
# Time per epoch (model/function): (11.436s/ 0.259s)
# Time per epoch per 1k trials: 0.052s
# Current time: 2023-01-28 23:36:26.632395
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 118.302991, R2: 0.04,  best epoch: 9,  secs per epoch: 0.350s,  secs epoch*1k trials: 0.070s
# early stop!
# Final loss: 118.3029909134 , R2: 0.04
# Total time (model/function): (219.014s / 6.657s)
# Time per epoch (model/function): (11.527s/ 0.350s)
# Time per epoch per 1k trials: 0.070s
# Current time: 2023-01-28 23:36:33.922076
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 117.784741, R2: 0.04,  best epoch: 9,  secs per epoch: 0.411s,  secs epoch*1k trials: 0.082s
# early stop!
# Final loss: 117.7847414017 , R2: 0.04
# Total time (model/function): (220.157s / 7.800s)
# Time per epoch (model/function): (11.587s/ 0.411s)
# Time per epoch per 1k trials: 0.082s
# Current time: 2023-01-28 23:36:42.571359
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2  last_loss
# 3            0             0      2   0.193731     20       0.905678  117.784047  0.038599  118.86054
# 5            0             0      1   0.205077     20       0.469730  118.302217  0.038612  118.86054
# 4            0             0      0   0.226558     20       0.000220  118.860279  0.038612  118.86054
# 2            0             0     -1   0.221337     20       0.000127  118.860390  0.038563  118.86054
# 1            0             0     -2   0.216116     20       0.000032  118.860502  0.038514  118.86054
# 0            0             0      0   0.193731     20       0.000000  118.860540  0.038432  118.86054
# 0 0 2 0.19373054802417755 20 0.9056775778676033 117.78404712677002 0.03859899661150756
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 117.784745, R2: 0.04,  best epoch: 9,  secs per epoch: 0.337s,  secs epoch*1k trials: 0.067s
# early stop!
# Final loss: 117.7847452164 , R2: 0.04
# Total time (model/function): (226.564s / 6.407s)
# Time per epoch (model/function): (11.924s/ 0.337s)
# Time per epoch per 1k trials: 0.067s
# Current time: 2023-01-28 23:36:49.653258
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 117.784704, R2: 0.04,  best epoch: 9,  secs per epoch: 0.410s,  secs epoch*1k trials: 0.082s
# early stop!
# Final loss: 117.7847042084 , R2: 0.04
# Total time (model/function): (227.948s / 7.791s)
# Time per epoch (model/function): (11.997s/ 0.410s)
# Time per epoch per 1k trials: 0.082s
# Current time: 2023-01-28 23:36:57.945982
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 117.784649, R2: 0.04,  best epoch: 9,  secs per epoch: 0.440s,  secs epoch*1k trials: 0.088s
# early stop!
# Final loss: 117.7846488953 , R2: 0.04
# Total time (model/function): (228.508s / 8.351s)
# Time per epoch (model/function): (12.027s/ 0.440s)
# Time per epoch per 1k trials: 0.088s
# Current time: 2023-01-28 23:37:06.831785
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 117.329694, R2: 0.04,  best epoch: 9,  secs per epoch: 0.313s,  secs epoch*1k trials: 0.063s
# early stop!
# Final loss: 117.3296937943 , R2: 0.04
# Total time (model/function): (226.105s / 5.948s)
# Time per epoch (model/function): (11.900s/ 0.313s)
# Time per epoch per 1k trials: 0.063s
# Current time: 2023-01-28 23:37:13.295215
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.952823, R2: 0.04,  best epoch: 9,  secs per epoch: 0.467s,  secs epoch*1k trials: 0.093s
# early stop!
# Final loss: 116.9528226852 , R2: 0.04
# Total time (model/function): (229.034s / 8.877s)
# Time per epoch (model/function): (12.054s/ 0.467s)
# Time per epoch per 1k trials: 0.093s
# Current time: 2023-01-28 23:37:22.887106
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 4            0             0      2   0.146047     20       0.706308  116.952128  0.038558  117.784047
# 2            0             0      1   0.171730     20       0.386408  117.328920  0.038532  117.784047
# 3            0             0      0   0.183596     20       0.000217  117.783792  0.038552  117.784047
# 1            0             0     -1   0.178375     20       0.000117  117.783910  0.038502  117.784047
# 0            0             0     -2   0.173155     20       0.000027  117.784016  0.038452  117.784047
# 5            0             0      0   0.146047     20       0.000000  117.784047  0.038599  117.784047
# 0 0 2 0.14604687690734863 20 0.7063084829605801 116.95212841033936 0.03855756802500809
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.952830, R2: 0.04,  best epoch: 9,  secs per epoch: 0.378s,  secs epoch*1k trials: 0.076s
# early stop!
# Final loss: 116.9528303146 , R2: 0.04
# Total time (model/function): (236.212s / 7.178s)
# Time per epoch (model/function): (12.432s/ 0.378s)
# Time per epoch per 1k trials: 0.076s
# Current time: 2023-01-28 23:37:31.123918
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.952782, R2: 0.04,  best epoch: 9,  secs per epoch: 0.458s,  secs epoch*1k trials: 0.092s
# early stop!
# Final loss: 116.9527816772 , R2: 0.04
# Total time (model/function): (237.731s / 8.698s)
# Time per epoch (model/function): (12.512s/ 0.458s)
# Time per epoch per 1k trials: 0.092s
# Current time: 2023-01-28 23:37:40.485715
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.952731, R2: 0.04,  best epoch: 9,  secs per epoch: 0.404s,  secs epoch*1k trials: 0.081s
# early stop!
# Final loss: 116.9527311325 , R2: 0.04
# Total time (model/function): (236.706s / 7.673s)
# Time per epoch (model/function): (12.458s/ 0.404s)
# Time per epoch per 1k trials: 0.081s
# Current time: 2023-01-28 23:37:48.788294
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.601848, R2: 0.04,  best epoch: 9,  secs per epoch: 0.484s,  secs epoch*1k trials: 0.097s
# early stop!
# Final loss: 116.6018476486 , R2: 0.04
# Total time (model/function): (238.233s / 9.200s)
# Time per epoch (model/function): (12.539s/ 0.484s)
# Time per epoch per 1k trials: 0.097s
# Current time: 2023-01-28 23:37:58.463934
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.445103, R2: 0.04,  best epoch: 9,  secs per epoch: 0.458s,  secs epoch*1k trials: 0.092s
# early stop!
# Final loss: 116.4451026917 , R2: 0.04
# Total time (model/function): (237.742s / 8.708s)
# Time per epoch (model/function): (12.513s/ 0.458s)
# Time per epoch per 1k trials: 0.092s
# Current time: 2023-01-28 23:38:07.838064
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 0            0             0      2   0.124769     20       0.434125  116.444410  0.038544  116.952128
# 4            0             0      1   0.134274     20       0.300167  116.601077  0.038631  116.952128
# 5            0             0      0   0.155618     20       0.000222  116.951869  0.038660  116.952128
# 3            0             0     -1   0.150397     20       0.000117  116.951991  0.038611  116.952128
# 2            0             0     -2   0.145177     20       0.000020  116.952106  0.038561  116.952128
# 1            0             0      0   0.124769     20       0.000000  116.952128  0.038558  116.952128
# 0 0 2 0.12476855516433716 20 0.43412470824070104 116.44441032409668 0.03854420437854866
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.445101, R2: 0.04,  best epoch: 9,  secs per epoch: 0.432s,  secs epoch*1k trials: 0.086s
# early stop!
# Final loss: 116.4451007843 , R2: 0.04
# Total time (model/function): (245.946s / 8.204s)
# Time per epoch (model/function): (12.945s/ 0.432s)
# Time per epoch per 1k trials: 0.086s
# Current time: 2023-01-28 23:38:16.751179
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.445053, R2: 0.04,  best epoch: 9,  secs per epoch: 0.472s,  secs epoch*1k trials: 0.094s
# early stop!
# Final loss: 116.4450531006 , R2: 0.04
# Total time (model/function): (246.705s / 8.963s)
# Time per epoch (model/function): (12.984s/ 0.472s)
# Time per epoch per 1k trials: 0.094s
# Current time: 2023-01-28 23:38:26.202357
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.445008, R2: 0.04,  best epoch: 9,  secs per epoch: 0.516s,  secs epoch*1k trials: 0.103s
# early stop!
# Final loss: 116.4450082779 , R2: 0.04
# Total time (model/function): (247.541s / 9.799s)
# Time per epoch (model/function): (13.028s/ 0.516s)
# Time per epoch per 1k trials: 0.103s
# Current time: 2023-01-28 23:38:36.707005
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 116.073121, R2: 0.04,  best epoch: 9,  secs per epoch: 0.277s,  secs epoch*1k trials: 0.055s
# early stop!
# Final loss: 116.0731210709 , R2: 0.04
# Total time (model/function): (243.003s / 5.261s)
# Time per epoch (model/function): (12.790s/ 0.277s)
# Time per epoch per 1k trials: 0.055s
# Current time: 2023-01-28 23:38:42.518240
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.579101, R2: 0.04,  best epoch: 9,  secs per epoch: 0.250s,  secs epoch*1k trials: 0.050s
# early stop!
# Final loss: 115.5791006088 , R2: 0.04
# Total time (model/function): (242.487s / 4.745s)
# Time per epoch (model/function): (12.762s/ 0.250s)
# Time per epoch per 1k trials: 0.050s
# Current time: 2023-01-28 23:38:47.647289
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2  last_loss
# 1            0             0      2   0.084257     20       0.743700  115.578413  0.038511  116.44441
# 4            0             0      1   0.103172     20       0.319521  116.072346  0.038570  116.44441
# 5            0             0      0   0.126266     20       0.000220  116.444154  0.038571  116.44441
# 2            0             0     -1   0.121045     20       0.000124  116.444265  0.038522  116.44441
# 0            0             0     -2   0.115825     20       0.000028  116.444378  0.038473  116.44441
# 3            0             0      0   0.084257     20       0.000000  116.444410  0.038544  116.44441
# 0 0 2 0.08425656706094742 20 0.743700201703815 115.57841300964355 0.03851119818423199
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.579101, R2: 0.04,  best epoch: 9,  secs per epoch: 0.326s,  secs epoch*1k trials: 0.065s
# early stop!
# Final loss: 115.5791006088 , R2: 0.04
# Total time (model/function): (248.677s / 6.190s)
# Time per epoch (model/function): (13.088s/ 0.326s)
# Time per epoch per 1k trials: 0.065s
# Current time: 2023-01-28 23:38:54.510893
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.579056, R2: 0.04,  best epoch: 9,  secs per epoch: 0.397s,  secs epoch*1k trials: 0.079s
# early stop!
# Final loss: 115.5790557861 , R2: 0.04
# Total time (model/function): (250.032s / 7.545s)
# Time per epoch (model/function): (13.160s/ 0.397s)
# Time per epoch per 1k trials: 0.079s
# Current time: 2023-01-28 23:39:02.679558
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.579009, R2: 0.04,  best epoch: 9,  secs per epoch: 0.397s,  secs epoch*1k trials: 0.079s
# early stop!
# Final loss: 115.5790090561 , R2: 0.04
# Total time (model/function): (250.036s / 7.550s)
# Time per epoch (model/function): (13.160s/ 0.397s)
# Time per epoch per 1k trials: 0.079s
# Current time: 2023-01-28 23:39:10.784056
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352778, R2: 0.04,  best epoch: 9,  secs per epoch: 0.430s,  secs epoch*1k trials: 0.086s
# early stop!
# Final loss: 115.3527784348 , R2: 0.04
# Total time (model/function): (250.658s / 8.172s)
# Time per epoch (model/function): (13.193s/ 0.430s)
# Time per epoch per 1k trials: 0.086s
# Current time: 2023-01-28 23:39:19.350257
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352818, R2: 0.04,  best epoch: 9,  secs per epoch: 0.340s,  secs epoch*1k trials: 0.068s
# early stop!
# Final loss: 115.3528175354 , R2: 0.04
# Total time (model/function): (248.942s / 6.455s)
# Time per epoch (model/function): (13.102s/ 0.340s)
# Time per epoch per 1k trials: 0.068s
# Current time: 2023-01-28 23:39:26.225828
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 4            0             0      1   0.072739     20       0.195895  115.352001  0.038604  115.578413
# 3            0             0      2   0.052205     20       0.195785  115.352128  0.038603  115.578413
# 5            0             0      0   0.097213     20       0.000229  115.578149  0.038613  115.578413
# 2            0             0     -1   0.091993     20       0.000132  115.578260  0.038564  115.578413
# 1            0             0     -2   0.086772     20       0.000033  115.578375  0.038515  115.578413
# 0            0             0      0   0.052205     20       0.000000  115.578413  0.038511  115.578413
# 0 0 1 0.0727393627166748 20 0.1958945563987945 115.35200119018555 0.038603558912076785
# action (expand left, expand right, shift): (0, 0, 1)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352825, R2: 0.04,  best epoch: 9,  secs per epoch: 0.356s,  secs epoch*1k trials: 0.071s
# early stop!
# Final loss: 115.3528251648 , R2: 0.04
# Total time (model/function): (257.413s / 6.755s)
# Time per epoch (model/function): (13.548s/ 0.356s)
# Time per epoch per 1k trials: 0.071s
# Current time: 2023-01-28 23:39:33.982977
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352780, R2: 0.04,  best epoch: 9,  secs per epoch: 0.428s,  secs epoch*1k trials: 0.086s
# early stop!
# Final loss: 115.3527803421 , R2: 0.04
# Total time (model/function): (258.793s / 8.135s)
# Time per epoch (model/function): (13.621s/ 0.428s)
# Time per epoch per 1k trials: 0.086s
# Current time: 2023-01-28 23:39:42.657069
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352732, R2: 0.04,  best epoch: 9,  secs per epoch: 0.348s,  secs epoch*1k trials: 0.070s
# early stop!
# Final loss: 115.3527317047 , R2: 0.04
# Total time (model/function): (257.265s / 6.607s)
# Time per epoch (model/function): (13.540s/ 0.348s)
# Time per epoch per 1k trials: 0.070s
# Current time: 2023-01-28 23:39:49.751082
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352775, R2: 0.04,  best epoch: 9,  secs per epoch: 0.422s,  secs epoch*1k trials: 0.084s
# early stop!
# Final loss: 115.3527746201 , R2: 0.04
# Total time (model/function): (258.683s / 8.024s)
# Time per epoch (model/function): (13.615s/ 0.422s)
# Time per epoch per 1k trials: 0.084s
# Current time: 2023-01-28 23:39:58.228880
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352817, R2: 0.04,  best epoch: 9,  secs per epoch: 0.450s,  secs epoch*1k trials: 0.090s
# early stop!
# Final loss: 115.3528165817 , R2: 0.04
# Total time (model/function): (259.202s / 8.544s)
# Time per epoch (model/function): (13.642s/ 0.450s)
# Time per epoch per 1k trials: 0.090s
# Current time: 2023-01-28 23:40:07.175635
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 5            0             0      0   0.072755     20       0.000126  115.351855  0.038618  115.352001
# 2            0             0     -1   0.067534     20       0.000032  115.351964  0.038569  115.352001
# 3            0             0      1   0.046984     20       0.000017  115.351982  0.038580  115.352001
# 4            0             0      0   0.046984     20       0.000000  115.352001  0.038604  115.352001
# 0            0             0     -2   0.067534     20      -0.000082  115.352096  0.038557  115.352001
# 1            0             0      2   0.046984     20      -0.000095  115.352111  0.038567  115.352001
# 0 0 0 0.0727546438574791 20 0.0001264929683964346 115.35185527801514 0.038618242297318583
# action (expand left, expand right, shift): (0, 0, 0)
#
# This was the last iteration. Done with kernel shift optimization...
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
# kernel grad (0) = 1
# kernel grad (1) = 1
# kernel grad (2) = 1
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 0.842375, R2: 0.04,  best epoch: 9,  secs per epoch: 0.382 s,  secs epoch*1k trials: 0.076s
# Epoch: 21, Loss: 0.842210, R2: 0.04,  best epoch: 19,  secs per epoch: 0.379 s,  secs epoch*1k trials: 0.076s
# Epoch: 31, Loss: 0.842062, R2: 0.04,  best epoch: 29,  secs per epoch: 0.380 s,  secs epoch*1k trials: 0.076s
# Epoch: 41, Loss: 0.841893, R2: 0.04,  best epoch: 39,  secs per epoch: 0.392 s,  secs epoch*1k trials: 0.078s
# Epoch: 51, Loss: 0.841711, R2: 0.04,  best epoch: 49,  secs per epoch: 0.383 s,  secs epoch*1k trials: 0.077s
# Epoch: 61, Loss: 0.841521, R2: 0.04,  best epoch: 59,  secs per epoch: 0.396 s,  secs epoch*1k trials: 0.079s
# Epoch: 71, Loss: 0.841332, R2: 0.04,  best epoch: 69,  secs per epoch: 0.400 s,  secs epoch*1k trials: 0.080s
# Epoch: 81, Loss: 0.841155, R2: 0.04,  best epoch: 79,  secs per epoch: 0.390 s,  secs epoch*1k trials: 0.078s
# Epoch: 91, Loss: 0.841002, R2: 0.04,  best epoch: 89,  secs per epoch: 0.378 s,  secs epoch*1k trials: 0.076s
# Final loss: 0.8408899978 , R2: 0.04
# Total time (model/function): (293.955s / 36.690s)
# Time per epoch (model/function): (2.969s/ 0.371s)
# ...
# Time per epoch (model/function): (1.806s/ 0.094s)
# Time per epoch per 1k trials: 0.019s
# Current time: 2023-01-28 23:43:46.877440
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2  last_loss
# 1            0             0      2   0.074649     20       0.220542  115.581790  0.038360  115.83726
# 5            0             0      1   0.098010     20       0.160122  115.651779  0.038431  115.83726
# 4            0             0      0   0.104170     20       0.000221  115.837004  0.038425  115.83726
# 2            0             0     -1   0.098949     20       0.000124  115.837116  0.038375  115.83726
# 0            0             0     -2   0.093728     20       0.000027  115.837229  0.038324  115.83726
# 3            0             0      0   0.074649     20       0.000000  115.837260  0.038397  115.83726
# 0 0 2 0.07464870810508728 20 0.22054240175895162 115.58178997039795 0.03835975980482487
# action (expand left, expand right, shift): (0, 0, 2)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.582475, R2: 0.04,  best epoch: 9,  secs per epoch: 0.100s,  secs epoch*1k trials: 0.020s
# early stop!
# Final loss: 115.5824747086 , R2: 0.04
# Total time (model/function): (36.209s / 1.891s)
# Time per epoch (model/function): (1.906s/ 0.100s)
# Time per epoch per 1k trials: 0.020s
# Current time: 2023-01-28 23:43:49.005819
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.582431, R2: 0.04,  best epoch: 9,  secs per epoch: 0.089s,  secs epoch*1k trials: 0.018s
# early stop!
# Final loss: 115.5824308395 , R2: 0.04
# Total time (model/function): (36.011s / 1.693s)
# Time per epoch (model/function): (1.895s/ 0.089s)
# Time per epoch per 1k trials: 0.018s
# Current time: 2023-01-28 23:43:50.875134
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.582387, R2: 0.04,  best epoch: 9,  secs per epoch: 0.089s,  secs epoch*1k trials: 0.018s
# early stop!
# Final loss: 115.5823869705 , R2: 0.04
# Total time (model/function): (36.015s / 1.697s)
# Time per epoch (model/function): (1.896s/ 0.089s)
# Time per epoch per 1k trials: 0.018s
# Current time: 2023-01-28 23:43:52.727186
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352680, R2: 0.04,  best epoch: 9,  secs per epoch: 0.084s,  secs epoch*1k trials: 0.017s
# early stop!
# Final loss: 115.3526802063 , R2: 0.04
# Total time (model/function): (35.912s / 1.594s)
# Time per epoch (model/function): (1.890s/ 0.084s)
# Time per epoch per 1k trials: 0.017s
# Current time: 2023-01-28 23:43:54.455911
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352724, R2: 0.04,  best epoch: 9,  secs per epoch: 0.095s,  secs epoch*1k trials: 0.019s
# early stop!
# Final loss: 115.3527240753 , R2: 0.04
# Total time (model/function): (36.122s / 1.804s)
# Time per epoch (model/function): (1.901s/ 0.095s)
# Time per epoch per 1k trials: 0.019s
# Current time: 2023-01-28 23:43:56.406979
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2  last_loss
# 3            0             0      1   0.062914     20       0.198894  115.351905  0.038399  115.58179
# 2            0             0      2   0.052208     20       0.198785  115.352031  0.038393  115.58179
# 5            0             0      0   0.085069     20       0.000226  115.581529  0.038464  115.58179
# 4            0             0     -1   0.079849     20       0.000128  115.581642  0.038414  115.58179
# 1            0             0     -2   0.074628     20       0.000035  115.581749  0.038364  115.58179
# 0            0             0      0   0.052208     20       0.000000  115.581790  0.038360  115.58179
# 0 0 1 0.0629136860370636 20 0.19889387539095568 115.35190486907959 0.03839934813191781
# action (expand left, expand right, shift): (0, 0, 1)
#
#
# SHIFT OPTIMIZATION (again)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352722, R2: 0.04,  best epoch: 9,  secs per epoch: 0.101s,  secs epoch*1k trials: 0.020s
# early stop!
# Final loss: 115.3527221680 , R2: 0.04
# Total time (model/function): (37.840s / 1.928s)
# Time per epoch (model/function): (1.992s/ 0.101s)
# Time per epoch per 1k trials: 0.020s
# Current time: 2023-01-28 23:43:58.603315
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352675, R2: 0.04,  best epoch: 9,  secs per epoch: 0.102s,  secs epoch*1k trials: 0.020s
# early stop!
# Final loss: 115.3526754379 , R2: 0.04
# Total time (model/function): (37.859s / 1.947s)
# Time per epoch (model/function): (1.993s/ 0.102s)
# Time per epoch per 1k trials: 0.020s
# Current time: 2023-01-28 23:44:00.694669
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352630, R2: 0.04,  best epoch: 9,  secs per epoch: 0.119s,  secs epoch*1k trials: 0.024s
# early stop!
# Final loss: 115.3526296616 , R2: 0.04
# Total time (model/function): (38.181s / 2.269s)
# Time per epoch (model/function): (2.010s/ 0.119s)
# Time per epoch per 1k trials: 0.024s
# Current time: 2023-01-28 23:44:03.121415
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352676, R2: 0.04,  best epoch: 9,  secs per epoch: 0.101s,  secs epoch*1k trials: 0.020s
# early stop!
# Final loss: 115.3526763916 , R2: 0.04
# Total time (model/function): (37.835s / 1.923s)
# Time per epoch (model/function): (1.991s/ 0.101s)
# Time per epoch per 1k trials: 0.020s
# Current time: 2023-01-28 23:44:05.215998
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 20, Loss: 115.352723, R2: 0.04,  best epoch: 9,  secs per epoch: 0.095s,  secs epoch*1k trials: 0.019s
# early stop!
# Final loss: 115.3527231216 , R2: 0.04
# Total time (model/function): (37.722s / 1.810s)
# Time per epoch (model/function): (1.985s/ 0.095s)
# Time per epoch per 1k trials: 0.019s
# Current time: 2023-01-28 23:44:07.184068
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 5            0             0      0   0.062936     20       0.000128  115.351757  0.038415  115.351905
# 2            0             0     -1   0.057715     20       0.000031  115.351869  0.038365  115.351905
# 3            0             0      1   0.046987     20       0.000015  115.351888  0.038370  115.351905
# 4            0             0      0   0.046987     20       0.000000  115.351905  0.038399  115.351905
# 0            0             0     -2   0.057715     20      -0.000079  115.351996  0.038353  115.351905
# 1            0             0      2   0.046987     20      -0.000096  115.352015  0.038356  115.351905
# 0 0 0 0.06293553113937378 20 0.00012814657825611009 115.35175704956055 0.03841485465871075
# action (expand left, expand right, shift): (0, 0, 0)
#
# This was the last iteration. Done with kernel shift optimization...
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
# kernel grad (0) = 1
# kernel grad (1) = 1
# kernel grad (2) = 1
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 0.842436, R2: 0.04,  best epoch: 9,  secs per epoch: 0.110 s,  secs epoch*1k trials: 0.022s
# Epoch: 21, Loss: 0.842261, R2: 0.04,  best epoch: 19,  secs per epoch: 0.108 s,  secs epoch*1k trials: 0.022s
# Epoch: 31, Loss: 0.842101, R2: 0.04,  best epoch: 29,  secs per epoch: 0.104 s,  secs epoch*1k trials: 0.021s
# Epoch: 41, Loss: 0.841919, R2: 0.04,  best epoch: 39,  secs per epoch: 0.099 s,  secs epoch*1k trials: 0.020s
# Epoch: 51, Loss: 0.841723, R2: 0.04,  best epoch: 49,  secs per epoch: 0.101 s,  secs epoch*1k trials: 0.020s
# Epoch: 61, Loss: 0.841519, R2: 0.04,  best epoch: 59,  secs per epoch: 0.099 s,  secs epoch*1k trials: 0.020s
# Epoch: 71, Loss: 0.841318, R2: 0.04,  best epoch: 69,  secs per epoch: 0.097 s,  secs epoch*1k trials: 0.019s
# Epoch: 81, Loss: 0.841130, R2: 0.04,  best epoch: 79,  secs per epoch: 0.096 s,  secs epoch*1k trials: 0.019s
# Epoch: 91, Loss: 0.840970, R2: 0.04,  best epoch: 89,  secs per epoch: 0.098 s,  secs epoch*1k trials: 0.020s
# Final loss: 0.8408542499 , R2: 0.04
# Total time (model/function): (47.673s / 9.492s)
# Time per epoch (model/function): (0.482s/ 0.096s)
# Time per epoch per 1k trials: 0.019s
# Current time: 2023-01-28 23:44:16.893234
# best loss 0.840854249894619
# current r2 values by newly added kernel
# [0.038246981955323056, 0.03826647788951132, 0.04360050985865094]
# optimizing feature type dinuc
# setting grad status of kernel (mono, dinuc) at 0 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 1 to (0, 0)
# setting grad status of kernel (mono, dinuc) at 2 to (0, 1)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 115.544693, R2: 0.04,  best epoch: 7,  secs per epoch: 0.094 s,  secs epoch*1k trials: 0.019s
# Epoch: 18, Loss: 115.546798, R2: 0.04,  best epoch: 7,  secs per epoch: 0.092s,  secs epoch*1k trials: 0.018s
# early stop!
# Final loss: 115.5467977524 , R2: 0.04
# Total time (model/function): (49.236s / 1.563s)
# Time per epoch (model/function): (2.896s/ 0.092s)
# Time per epoch per 1k trials: 0.018s
# Current time: 2023-01-28 23:44:18.598772
#
# WIDTH OPTIMIZATION (first)...
# Reached maximum w. Stop...
#
# SHIFT OPTIMIZATION (first)...
# options to try [[0, 0, -2], [0, 0, -1], [0, 0, 0], [0, 0, 1], [0, 0, 2]]
# next expand left: 0, next expand right: 0, shift: -2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 14, Loss: 115.577989, R2: 0.04,  best epoch: 3,  secs per epoch: 0.092s,  secs epoch*1k trials: 0.018s
# early stop!
# Final loss: 115.5779886246 , R2: 0.04
# Total time (model/function): (50.426s / 1.190s)
# Time per epoch (model/function): (3.879s/ 0.092s)
# Time per epoch per 1k trials: 0.018s
# Current time: 2023-01-28 23:44:19.863556
#
# next expand left: 0, next expand right: 0, shift: -1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 115.562312, R2: 0.04,  best epoch: 8,  secs per epoch: 0.085s,  secs epoch*1k trials: 0.017s
# early stop!
# Final loss: 115.5623121262 , R2: 0.04
# Total time (model/function): (50.771s / 1.535s)
# Time per epoch (model/function): (2.821s/ 0.085s)
# Time per epoch per 1k trials: 0.017s
# Current time: 2023-01-28 23:44:21.536494
#
# next expand left: 0, next expand right: 0, shift: 0
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 18, Loss: 115.546813, R2: 0.04,  best epoch: 7,  secs per epoch: 0.087s,  secs epoch*1k trials: 0.017s
# early stop!
# Final loss: 115.5468130112 , R2: 0.04
# Total time (model/function): (50.711s / 1.475s)
# Time per epoch (model/function): (2.983s/ 0.087s)
# Time per epoch per 1k trials: 0.017s
# Current time: 2023-01-28 23:44:23.148374
#
# next expand left: 0, next expand right: 0, shift: 1
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 19, Loss: 115.562313, R2: 0.04,  best epoch: 8,  secs per epoch: 0.084s,  secs epoch*1k trials: 0.017s
# early stop!
# Final loss: 115.5623130798 , R2: 0.04
# Total time (model/function): (50.746s / 1.510s)
# Time per epoch (model/function): (2.819s/ 0.084s)
# Time per epoch per 1k trials: 0.017s
# Current time: 2023-01-28 23:44:24.792578
#
# next expand left: 0, next expand right: 0, shift: 2
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 300
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 14, Loss: 115.577987, R2: 0.04,  best epoch: 3,  secs per epoch: 0.088s,  secs epoch*1k trials: 0.018s
# early stop!
# Final loss: 115.5779867172 , R2: 0.04
# Total time (model/function): (50.386s / 1.150s)
# Time per epoch (model/function): (3.876s/ 0.088s)
# Time per epoch per 1k trials: 0.018s
# Current time: 2023-01-28 23:44:26.077073
#
# sorted
#    expand.left  expand.right  shift  pos_w_sum  width  loss_diff_pct        loss        r2   last_loss
# 4            0             0      0   3.907480     20       0.000000  115.542434  0.043802  115.542434
# 5            0             0      0   4.271315     20      -0.000035  115.542475  0.043812  115.542434
# 1            0             0      2   3.907480     20      -0.010849  115.554969  0.043472  115.542434
# 0            0             0     -2   3.905773     20      -0.010850  115.554970  0.043471  115.542434
# 2            0             0     -1   4.095081     20      -0.011799  115.556067  0.043655  115.542434
# 3            0             0      1   4.096404     20      -0.011799  115.556067  0.043656  115.542434
# 0 0 0 3.907479763031006 20 0.0 115.5424337387085 0.043801998902873174
# action (expand left, expand right, shift): (0, 0, 0)
#
# This was the last iteration. Done with kernel shift optimization...
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
# kernel grad (0) = 1
# kernel grad (1) = 1
# kernel grad (2) = 1
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 100
# early_stopping: 10
# lr= 0.01, weight_decay= 0.001, dir weight= 0
# Epoch: 11, Loss: 0.840793, R2: 0.04,  best epoch: 9,  secs per epoch: 0.096 s,  secs epoch*1k trials: 0.019s
# Epoch: 21, Loss: 0.840721, R2: 0.04,  best epoch: 19,  secs per epoch: 0.091 s,  secs epoch*1k trials: 0.018s
# Epoch: 31, Loss: 0.840658, R2: 0.04,  best epoch: 29,  secs per epoch: 0.089 s,  secs epoch*1k trials: 0.018s
# Epoch: 41, Loss: 0.840608, R2: 0.04,  best epoch: 39,  secs per epoch: 0.088 s,  secs epoch*1k trials: 0.018s
# Epoch: 51, Loss: 0.840559, R2: 0.04,  best epoch: 49,  secs per epoch: 0.087 s,  secs epoch*1k trials: 0.017s
# Epoch: 61, Loss: 0.840512, R2: 0.04,  best epoch: 59,  secs per epoch: 0.087 s,  secs epoch*1k trials: 0.017s
# Epoch: 71, Loss: 0.840468, R2: 0.04,  best epoch: 69,  secs per epoch: 0.087 s,  secs epoch*1k trials: 0.017s
# Epoch: 81, Loss: 0.840428, R2: 0.04,  best epoch: 79,  secs per epoch: 0.087 s,  secs epoch*1k trials: 0.017s
# Epoch: 91, Loss: 0.840395, R2: 0.05,  best epoch: 89,  secs per epoch: 0.086 s,  secs epoch*1k trials: 0.017s
# Final loss: 0.8403726369 , R2: 0.05
# Total time (model/function): (57.708s / 8.472s)
# Time per epoch (model/function): (0.583s/ 0.086s)
# Time per epoch per 1k trials: 0.017s
# Current time: 2023-01-28 23:44:34.755173
# best loss 0.8403726369142532
# current r2 values by newly added kernel
# [0.038246981955323056, 0.03826647788951132, 0.04360050985865094, 0.045106268864211096]
#
# optimization finished:
# total time: 57.70810842514038s
# Time per epoch (total): 0.577 s
# ##DONE....
#
#
# total time: 156.011 s

# %%
total_time[-2] / total_time[-1]
# Out:
# 5.877846729961968

# %%
for m, best_loss in models:
    print(m.optimize_neg_weight, m.optimize_kernel_rel, m.optimize_sym_weight)
