# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import anndata.logging

import mubind as mb
import numpy as np
import pandas as pd
import torch
import bindome as bd
bd.constants.ANNOTATIONS_DIRECTORY = 'annotations'
# mb.models.Mubind
import torch.optim as topti
import torch.utils.data as tdata
import matplotlib.pyplot as plt
import logomaker
import os
import scipy
import pickle
import seaborn
import numpy as np
import torch
import itertools
import glob

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))

# suppress numba deprecations warnings
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
import warnings
warnings.simplefilter('ignore', category=NumbaDeprecationWarning)
warnings.simplefilter('ignore', category=NumbaPendingDeprecationWarning)

# Use a GPU if available, as it should be faster.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))

from pathlib import Path
from tqdm.notebook import tqdm_notebook as tqdm
# Out:
# Using device: cuda:0
# Using device: cuda:0

# %%
import os
working_dir = os.path.expanduser('~/workspace/theislab/mubind/docs/notebooks/scatac')
if os.path.exists(working_dir):
    os.chdir(working_dir)

# %%
bd.constants.ANNOTATIONS_DIRECTORY = '../../../annotations'
if not os.path.exists(bd.constants.ANNOTATIONS_DIRECTORY):
    bd.constants.ANNOTATIONS_DIRECTORY = '.\\..\\..\\..\\..\\..\\..\\annotations'
os.path.exists(bd.constants.ANNOTATIONS_DIRECTORY)
print(bd.constants.ANNOTATIONS_DIRECTORY)
print(os.path.exists(bd.constants.ANNOTATIONS_DIRECTORY))
# Out:
# ../../../annotations
# True

# %%
import mubind as mb

# %%
pwms = mb.datasets.archetypes()
clu = mb.datasets.archetypes_clu()
anno = mb.datasets.archetypes_anno()
# Out:
# # motifs loaded 2179

# %% [markdown]
# The main motifs will be the seed ones

# %%
pwms_by_name = {}
for k, pwm in zip(anno['Seed_motif'], pwms):
    pwms_by_name[k] = pwm

reduced_groups = [p.to_numpy() for p in pwms]
len(reduced_groups)
# #
# # for pi, p in enumerate(reduced_groups):
#     print(pi, p.shape)
# Out:
# 286

# %% [markdown]
# Layer with only scATAC-seq

# %%
drive = '/mnt/f/'
drive = '/mnt/f/' if os.path.exists(drive) else 'F:/'
print(drive)
# Out:
# /mnt/f/

# %%
h5ad_path = os.path.join(drive, 'workspace/theislab/mubind/data/gbm_multiome_scdori/23_01_23_atac_compressed.h5ad')
print(h5ad_path)
# Out:
# /mnt/f/workspace/theislab/mubind/data/gbm_multiome_scdori/23_01_23_atac_compressed.h5ad

# %%
# !ls -ltrh /mnt/f/workspace/theislab/mubind/data/gbm_multiome_scdori/
# Out:
# total 70G
# -rwxrwxrwx 1 rio rio  25G May  1 19:07 rna_27_11_22.h5ad
# -rwxrwxrwx 1 rio rio  34G May  2 15:02 23_01_23_atac_compressed.h5ad
# -rwxrwxrwx 1 rio rio  58M May 16 15:29 rna_27_11_22_n2000.h5ad
# -rwxrwxrwx 1 rio rio 125M May 16 15:29 rna_27_11_22_n4500.h5ad
# -rwxrwxrwx 1 rio rio 189M May 16 15:29 rna_27_11_22_n7000.h5ad
# -rwxrwxrwx 1 rio rio 254M May 16 15:29 rna_27_11_22_n9500.h5ad
# -rwxrwxrwx 1 rio rio 322M May 16 15:29 rna_27_11_22_n12000.h5ad
# -rwxrwxrwx 1 rio rio 389M May 16 15:29 rna_27_11_22_n14500.h5ad
# -rwxrwxrwx 1 rio rio 456M May 16 15:29 rna_27_11_22_n17000.h5ad
# -rwxrwxrwx 1 rio rio 519M May 16 15:30 rna_27_11_22_n19500.h5ad
# -rwxrwxrwx 1 rio rio 536M May 16 15:30 rna_27_11_22_n20000.h5ad
# -rwxrwxrwx 1 rio rio 1.2G May 16 15:30 rna_27_11_22_n45000.h5ad
# -rwxrwxrwx 1 rio rio 1.9G May 16 15:30 rna_27_11_22_n70000.h5ad
# -rwxrwxrwx 1 rio rio 2.5G May 16 15:31 rna_27_11_22_n95000.h5ad
# -rwxrwxrwx 1 rio rio  22M May 16 22:45 rna_27_11_22_n10000.h5ad
# -rwxrwxrwx 1 rio rio 180M May 16 22:45 rna_27_11_22_n85000.h5ad
# -rwxrwxrwx 1 rio rio 340M May 16 22:46 rna_27_11_22_n160000.h5ad
# -rwxrwxrwx 1 rio rio 508M May 16 22:46 rna_27_11_22_n235000.h5ad
# -rwxrwxrwx 1 rio rio 678M May 16 22:46 rna_27_11_22_n310000.h5ad
# -rwxrwxrwx 1 rio rio 854M May 16 22:46 rna_27_11_22_n385000.h5ad
# -rwxrwxrwx 1 rio rio 1.1G May 16 22:47 rna_27_11_22_n460000.h5ad
# drwxrwxrwx 1 rio rio  512 Jun 28 02:34 scbasset_input
# -rwxrwxrwx 1 rio rio 913K Jun 28 03:12 23_01_23_atac_compressed_n1000.h5ad
# drwxrwxrwx 1 rio rio  512 Jun 28 10:01 scbasset_output
# -rwxrwxrwx 1 rio rio 3.7M Jul  3 17:37 23_01_23_atac_compressed_n3500.h5ad

# %%
import scanpy as sc
import os

n_sample_cells = 1000

bkp_path = os.path.join(h5ad_path.replace('.h5ad', '_n%i.h5ad' % n_sample_cells))
query_path = bkp_path if os.path.exists(bkp_path) else h5ad_path

# %%
os.path.exists(query_path), query_path
# Out:
# (True,
#  '/mnt/f/workspace/theislab/mubind/data/gbm_multiome_scdori/23_01_23_atac_compressed_n1000.h5ad')

# %%
print('trying to load...')
overwrite = False
if not os.path.exists(query_path) or overwrite:
    for n_next_sample_cells in range(1000, 25000, 2500):
        bkp_path = os.path.join(h5ad_path.replace('.h5ad', '_n%i.h5ad' % n_next_sample_cells))
        adata_full = None
        print(os.path.exists(bkp_path), bkp_path)
        if not os.path.exists(bkp_path) or overwrite:
            print(bkp_path)
            adata_full = sc.read_h5ad(h5ad_path) if adata_full is None else adata_full
            print('reading main object...')
            print(adata_full.shape)
            n_sample_peaks = int(n_next_sample_cells * 1.5)
            obs_sample = pd.Series(adata_full.obs_names).sample(n_next_sample_cells, random_state=n_next_sample_cells)
            var_sample = pd.Series(adata_full.var_names).sample(n_sample_peaks, random_state=n_next_sample_cells)
            # var_sample = atac.var.sort_values('acc_score_rank').index[:n_sample_peaks]
            ad = adata_full[adata_full.obs_names.isin(obs_sample), adata_full.var_names.isin(var_sample)].copy()
            print(ad.shape)
            ad.write(bkp_path, compression='lzf')
# Out:
# trying to load...

# %%
print('done. Attempting to load query object')
print(query_path)
adata_full = sc.read_h5ad(query_path)
# Out:
# done. Attempting to load query object
# /mnt/f/workspace/theislab/mubind/data/gbm_multiome_scdori/23_01_23_atac_compressed_n1000.h5ad

# %%
adata_full.shape
# Out:
# (1000, 1500)

# %% [markdown]
# For selection of features, adopt the accessibility score idea from EpiScanpy

# %%
acc = (adata_full.X != 0).sum(axis=0) / adata_full.shape[0]
acc_score = abs(.5 - acc)
adata_full.var['acc_score'] = acc_score.A.T
adata_full.var['acc_score_rank'] = adata_full.var['acc_score'].rank(ascending=False)

# %%
plt.hist(adata_full.var['acc_score'], bins=35)
# var_sample = atac.var.sort_values('acc_score_rank').index[:n_sample_peaks]
# Out:
# (array([  1.,   0.,   0.,   1.,   1.,   0.,   0.,   0.,   2.,   0.,   0.,
#           1.,   0.,   2.,   3.,   2.,   3.,   5.,   4.,   2.,   3.,   2.,
#           8.,   0.,  10.,   9.,   5.,  14.,  16.,  29.,  16.,  57.,  84.,
#         256., 964.]),
#  array([0.069     , 0.08131429, 0.09362857, 0.10594286, 0.11825714,
#         0.13057143, 0.14288571, 0.1552    , 0.16751429, 0.17982857,
#         0.19214286, 0.20445714, 0.21677143, 0.22908571, 0.2414    ,
#         0.25371429, 0.26602857, 0.27834286, 0.29065714, 0.30297143,
#         0.31528571, 0.3276    , 0.33991429, 0.35222857, 0.36454286,
#         0.37685714, 0.38917143, 0.40148571, 0.4138    , 0.42611429,
#         0.43842857, 0.45074286, 0.46305714, 0.47537143, 0.48768571,
#         0.5       ]),
#  <BarContainer object of 35 artists>)

# %%
adata_full.X = adata_full.X.astype('float32')

# %%
sc.pp.neighbors(adata_full, method='rapids')
# Out:
# WARNING: You’re trying to run this on 1500 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.tl.umap(adata_full, method='rapids')
# Out:
# WARNING: .obsp["connectivities"] have not been computed using umap

# %%
sc.pl.umap(adata_full)

# %%
# n_sample_cells = 500 # adata.shape[0]
# n_sample_peaks = n_sample_cells * 2 # adata.shape[1]

# %%
# adata = sc.pp.subsample(adata_full, n_obs=n_sample_cells, copy=True, random_state=100)
# print(adata.shape)
# var_sample = pd.Series(adata.var_names).sample(n_sample_peaks)
# adata = adata[:,adata.var_names.isin(var_sample)].copy()
# print(adata.shape)
adata = adata_full

# %% [markdown]
# Normalize peak sequences into fixed lengths

# %%
adata.var['chr'] = adata.var['seqnames']
adata.var['k.summit'] = adata.var['chr'].astype(str) + ':' + adata.var['start'].astype(str) + '-' + adata.var['end'].astype(str)

# %% [markdown]
# Retrieve sequences

# %%
n_seqs = 10000 # adata.shape[1] # None # 1000
seqs = mb.bindome.tl.get_sequences_from_bed(adata.var[['chr', 'start', 'end']].head(n_seqs), genome='hg38', uppercase=True)
                                            # gen_path='../../../annotations/dm6/genome/dm6.fa')
keys = set([s[0] for s in seqs])
adata = adata[:,adata.var['k.summit'].isin(keys)]
# seqs = [[s[0], s[1].upper()] for s in seqs[0]]
# Out:
# /tmp/tmp6kv_r7bh
# genome hg38 False
# options
# /mnt/c/Users/ignacio.ibarra/Dropbox/annotations/hg38/genome/hg38.fa
# True /mnt/c/Users/ignacio.ibarra/Dropbox/annotations/hg38/genome/hg38.fa
# running bedtools...
# bedtools getfasta -fi /mnt/c/Users/ignacio.ibarra/Dropbox/annotations/hg38/genome/hg38.fa -bed /tmp/tmp6kv_r7bh -fo /tmp/tmp3sbd0zrs

# %% [markdown]
# Select peaks with non-zero counts

# %%
# remove Ns
for s in seqs:
    if 'N' in s:
        assert False
    # seqs = [[s[0], s[1].replace('N', '')] for s in seqs]
counts = adata.X.A.T

next_data = pd.DataFrame(counts)
next_data['var'] = next_data.var(axis=1)
next_data.index = [str(i) + '-' + s[1] for i, s in enumerate(seqs)]
next_data.index.name = 'seq'
print(next_data.shape)
n_cells = adata.shape[0]
n_peaks = adata.shape[1]
top_var = next_data[['var']].sort_values('var', ascending=False).index[:n_peaks]
# next_data = next_data.head(10000)
next_data_sel = next_data.reindex(top_var) # .reset_index(drop=True)
del next_data_sel['var']
df = next_data_sel.copy() # sample
zero_counts = df.sum(axis=1) == 0
df = df[~zero_counts] # remove zeroes
df.shape

print('# cells', n_cells)
print('# peaks', n_peaks)

print('selected', df.shape)

df.index = [v.split('-')[1] for v in df.index]
df.index.name = 'seq'
# Out:
# (1500, 1001)
# # cells 1000
# # peaks 1500
# selected (1488, 1000)

# %% [markdown]
# ### This is the relatedness graph and used for dynamics filters learning

# %%
sc.pp.neighbors(adata)
ad = adata[:,~zero_counts].copy()

# %%
dataset = mb.datasets.SelexDataset(df, n_rounds=df.shape[1], enr_series=False)
len(set(dataset.batch))
n_batch = len(set(dataset.batch))
n_batch

train = tdata.DataLoader(dataset=dataset, batch_size=512, shuffle=True)

# %%
b = np.random.randint(0, 2, (3, 4))
conn = np.random.randint(0, 2, (4, 4))

# %%
n_kernels = len(reduced_groups)
# n_kernels = 8

# %%
import torch.optim as topti
import warnings

model_by_logdynamic = {}
n_epochs_intercept = 10
n_epochs_kernel = 10

selected_groups = pwms[:3]

for optimize_log_dynamic in [True, False]:
    warnings.filterwarnings("ignore")

    criterion = mb.tl.PoissonLoss()
    w = [r.shape[1] for r in selected_groups]
    model = mb.models.Mubind.make_model(train,
                                           n_kernels,
                                           criterion, kernels=[0, 2] + w,
                                           # use_dinuc=True, dinuc_mode='full',
                                           optimize_sym_weight=False,
                                           optimize_exp_barrier=True,
                                           optimize_prob_act=True,
                                           optimize_log_dynamic=optimize_log_dynamic,
                                           use_dinuc=False,
                                           device=device,
                                           p_dropout=0.8,
                                           prepare_knn=True,
                                           adata=adata,
                                           dinuc_mode=None).cuda()

    # initialize the reduce kernels
    for i, mono_best in enumerate(selected_groups):
        mono_best = mono_best.to_numpy()
        if mono_best.shape[-1] == 0:
            continue
        # print(mono_best.shape, model.binding_modes.conv_mono[i + 1].weight.shape)
        # print(model.binding_modes.conv_mono[i + 1].weight.device)
        new_w = mono_best.reshape([1, 1] + list(mono_best.shape))
        # print(i, i + 1)
        model.binding_modes.conv_mono[i + 2].weight = torch.nn.Parameter(torch.tensor(new_w, dtype=torch.float))
        # print(model.binding_modes.conv_mono[i + 1].weight.device)
    # move the model a final time to the GPU
    model = model.to(device)

    mb.pl.set_rcParams({'figure.figsize': [15, 3], 'figure.dpi': 90})
    mb.pl.logo(model, title=False, xticks=False, rowspan_dinuc=0, rowspan_mono=1, n_rows=5, n_cols=12) # n_cols=len(reduced_groups))

    mb.pl.set_rcParams({'figure.figsize': [20, 5], 'figure.dpi': 100})

    # mb.pl.conv(model, n_cols=2)
    import torch.nn as tnn
    
    model, best_loss = model.optimize_iterative(train, n_epochs=[n_epochs_intercept] + [n_epochs_kernel] * (n_kernels + 1),
                                                show_logo=False, use_mono=True, use_dinuc=False, dinuc_mode='local',
                                                opt_kernel_shift=[0, 0] + [0] * (n_kernels),
                                                opt_kernel_length=[0, 0] + [0] * (n_kernels),
                                                opt_one_step=True,
                                                shift_max=1, shift_step=1, optimiser=topti.Adam,
                                                skip_kernels=range(2, 500),
                                                n_batches=1, n_rounds=2, num_epochs_shift_factor=1, # log_etas=log_etas, # log_etas=log_etas,
                                                kernels = [0] + [2] + [20] * (n_kernels), r2_per_epoch=True,
                                                exp_max=8,
                                                early_stopping=250, log_each=1, w=20, max_w=20) #  target_dim=train.dataset.signal.shape[1])

    model_by_logdynamic[optimize_log_dynamic] = model
# Out:
# True
# 12
# order None
# 0 out of 5...
# done with mono
# current kernels
#
# Kernel to optimize 0
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 3008.144613, R2: 0.10,  best epoch: 0,  secs per epoch: 8.545 s,  secs epoch*1k trials: 5.743s curr time: 2023-07-04 16:45:38.152445
# Epoch:  3, Loss: 3008.123698, R2: 0.10,  best epoch: 1,  secs per epoch: 7.016 s,  secs epoch*1k trials: 4.715s curr time: 2023-07-04 16:45:43.639224
# Epoch:  4, Loss: 3008.101969, R2: 0.10,  best epoch: 2,  secs per epoch: 6.367 s,  secs epoch*1k trials: 4.279s curr time: 2023-07-04 16:45:48.708809
# Epoch:  5, Loss: 3008.079264, R2: 0.10,  best epoch: 3,  secs per epoch: 5.931 s,  secs epoch*1k trials: 3.986s curr time: 2023-07-04 16:45:53.332197
# Epoch:  6, Loss: 3008.056315, R2: 0.11,  best epoch: 4,  secs per epoch: 5.697 s,  secs epoch*1k trials: 3.829s curr time: 2023-07-04 16:45:58.092035
# Epoch:  7, Loss: 3008.031901, R2: 0.11,  best epoch: 5,  secs per epoch: 5.517 s,  secs epoch*1k trials: 3.708s curr time: 2023-07-04 16:46:02.711446
# Epoch:  8, Loss: 3008.006836, R2: 0.11,  best epoch: 6,  secs per epoch: 5.481 s,  secs epoch*1k trials: 3.683s curr time: 2023-07-04 16:46:07.974539
# Epoch:  9, Loss: 3007.980794, R2: 0.11,  best epoch: 7,  secs per epoch: 5.491 s,  secs epoch*1k trials: 3.690s curr time: 2023-07-04 16:46:13.536026
# Epoch: 10, Loss: 3007.954671, R2: 0.12,  best epoch: 8,  secs per epoch: 5.475 s,  secs epoch*1k trials: 3.679s curr time: 2023-07-04 16:46:18.879859
# Final loss: 3007.9546712240 , R2: 0.12
# Total time (model/function): (49.276s / 49.276s)
# Time per epoch (model/function): (5.475s/ 5.475s)
# Time per epoch per 1k trials: 3.679s
# Current time: 2023-07-04 16:46:19.921866
# optimization of dinuc is not necessary for the intercepts (kernel=0). Skip...
# current kernels
#
# Kernel to optimize 1
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 1 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 3007.902262, R2: 0.12,  best epoch: 0,  secs per epoch: 9.240 s,  secs epoch*1k trials: 6.210s curr time: 2023-07-04 16:46:29.163299
# Epoch:  3, Loss: 3007.876058, R2: 0.12,  best epoch: 1,  secs per epoch: 7.263 s,  secs epoch*1k trials: 4.881s curr time: 2023-07-04 16:46:34.448798
# Epoch:  4, Loss: 3007.849447, R2: 0.13,  best epoch: 2,  secs per epoch: 6.435 s,  secs epoch*1k trials: 4.325s curr time: 2023-07-04 16:46:39.228599
# Epoch:  5, Loss: 3007.822673, R2: 0.13,  best epoch: 3,  secs per epoch: 6.025 s,  secs epoch*1k trials: 4.049s curr time: 2023-07-04 16:46:44.022436
# Epoch:  6, Loss: 3007.795247, R2: 0.13,  best epoch: 4,  secs per epoch: 5.776 s,  secs epoch*1k trials: 3.882s curr time: 2023-07-04 16:46:48.802030
# Epoch:  7, Loss: 3007.768799, R2: 0.13,  best epoch: 5,  secs per epoch: 5.642 s,  secs epoch*1k trials: 3.792s curr time: 2023-07-04 16:46:53.774039
# Epoch:  8, Loss: 3007.740885, R2: 0.13,  best epoch: 6,  secs per epoch: 5.499 s,  secs epoch*1k trials: 3.696s curr time: 2023-07-04 16:46:58.418770
# Epoch:  9, Loss: 3007.713786, R2: 0.13,  best epoch: 7,  secs per epoch: 5.411 s,  secs epoch*1k trials: 3.636s curr time: 2023-07-04 16:47:03.209206
# Epoch: 10, Loss: 3007.686198, R2: 0.13,  best epoch: 8,  secs per epoch: 5.345 s,  secs epoch*1k trials: 3.592s curr time: 2023-07-04 16:47:08.027644
# Final loss: 3007.6861979167 , R2: 0.13
# Total time (model/function): (97.383s / 48.107s)
# Time per epoch (model/function): (10.820s/ 5.345s)
# Time per epoch per 1k trials: 3.592s
# Current time: 2023-07-04 16:47:09.064671
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 3007.598551, R2: 0.14,  best epoch: 0,  secs per epoch: 11.497 s,  secs epoch*1k trials: 7.727s curr time: 2023-07-04 16:47:20.563560
# Epoch:  3, Loss: 3007.571696, R2: 0.14,  best epoch: 1,  secs per epoch: 9.617 s,  secs epoch*1k trials: 6.463s curr time: 2023-07-04 16:47:28.299295
# Epoch:  4, Loss: 3007.544922, R2: 0.14,  best epoch: 2,  secs per epoch: 8.679 s,  secs epoch*1k trials: 5.833s curr time: 2023-07-04 16:47:35.102565
# Epoch:  5, Loss: 3007.518473, R2: 0.14,  best epoch: 3,  secs per epoch: 8.192 s,  secs epoch*1k trials: 5.506s curr time: 2023-07-04 16:47:41.835234
# Epoch:  6, Loss: 3007.492350, R2: 0.14,  best epoch: 4,  secs per epoch: 7.784 s,  secs epoch*1k trials: 5.231s curr time: 2023-07-04 16:47:47.987196
# Epoch:  7, Loss: 3007.466471, R2: 0.14,  best epoch: 5,  secs per epoch: 7.454 s,  secs epoch*1k trials: 5.010s curr time: 2023-07-04 16:47:53.791511
# Epoch:  8, Loss: 3007.440674, R2: 0.14,  best epoch: 6,  secs per epoch: 7.457 s,  secs epoch*1k trials: 5.011s curr time: 2023-07-04 16:48:01.264696
# Epoch:  9, Loss: 3007.415609, R2: 0.14,  best epoch: 7,  secs per epoch: 7.224 s,  secs epoch*1k trials: 4.855s curr time: 2023-07-04 16:48:06.856547
# Epoch: 10, Loss: 3007.390706, R2: 0.14,  best epoch: 8,  secs per epoch: 7.018 s,  secs epoch*1k trials: 4.716s curr time: 2023-07-04 16:48:12.228158
# Final loss: 3007.3907063802 , R2: 0.14
# Total time (model/function): (160.547s / 63.164s)
# Time per epoch (model/function): (17.839s/ 7.018s)
# Time per epoch per 1k trials: 4.717s
# Current time: 2023-07-04 16:48:13.315565
# best loss 3007.3907063802085
# current r2 values by newly added kernel
# [0.14286076502317324]
# optimizing feature type dinuc
# the optimization of dinucleotide features is skipped...
#
# optimization finished:
# total time: 160.54691410064697s
# Time per epoch (total): 0.056 s
# True
# 12
# order None
# 0 out of 5...
# done with mono
# current kernels
#
# Kernel to optimize 0
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 4.826855, R2: 0.10,  best epoch: 0,  secs per epoch: 9.406 s,  secs epoch*1k trials: 6.321s curr time: 2023-07-04 16:48:24.901032
# Epoch:  3, Loss: 4.805931, R2: 0.10,  best epoch: 1,  secs per epoch: 6.704 s,  secs epoch*1k trials: 4.505s curr time: 2023-07-04 16:48:28.902838
# Epoch:  4, Loss: 4.783657, R2: 0.10,  best epoch: 2,  secs per epoch: 5.756 s,  secs epoch*1k trials: 3.868s curr time: 2023-07-04 16:48:32.763635
# Epoch:  5, Loss: 4.761338, R2: 0.11,  best epoch: 3,  secs per epoch: 5.292 s,  secs epoch*1k trials: 3.557s curr time: 2023-07-04 16:48:36.664840
# Epoch:  6, Loss: 4.737867, R2: 0.11,  best epoch: 4,  secs per epoch: 5.010 s,  secs epoch*1k trials: 3.367s curr time: 2023-07-04 16:48:40.546309
# Epoch:  7, Loss: 4.713677, R2: 0.11,  best epoch: 5,  secs per epoch: 4.799 s,  secs epoch*1k trials: 3.225s curr time: 2023-07-04 16:48:44.289573
# Epoch:  8, Loss: 4.688690, R2: 0.11,  best epoch: 6,  secs per epoch: 4.637 s,  secs epoch*1k trials: 3.116s curr time: 2023-07-04 16:48:47.955680
# Epoch:  9, Loss: 4.663217, R2: 0.12,  best epoch: 7,  secs per epoch: 4.539 s,  secs epoch*1k trials: 3.051s curr time: 2023-07-04 16:48:51.810787
# Epoch: 10, Loss: 4.636976, R2: 0.12,  best epoch: 8,  secs per epoch: 4.538 s,  secs epoch*1k trials: 3.050s curr time: 2023-07-04 16:48:56.334599
# Final loss: 4.6369757652 , R2: 0.12
# Total time (model/function): (40.841s / 40.841s)
# Time per epoch (model/function): (4.538s/ 4.538s)
# Time per epoch per 1k trials: 3.050s
# Current time: 2023-07-04 16:48:57.651482
# optimization of dinuc is not necessary for the intercepts (kernel=0). Skip...
# current kernels
#
# Kernel to optimize 1
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 1 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 4.584473, R2: 0.12,  best epoch: 0,  secs per epoch: 8.996 s,  secs epoch*1k trials: 6.046s curr time: 2023-07-04 16:49:06.650270
# Epoch:  3, Loss: 4.557862, R2: 0.12,  best epoch: 1,  secs per epoch: 6.917 s,  secs epoch*1k trials: 4.648s curr time: 2023-07-04 16:49:11.487648
# Epoch:  4, Loss: 4.531601, R2: 0.13,  best epoch: 2,  secs per epoch: 5.952 s,  secs epoch*1k trials: 4.000s curr time: 2023-07-04 16:49:15.510686
# Epoch:  5, Loss: 4.505039, R2: 0.13,  best epoch: 3,  secs per epoch: 5.416 s,  secs epoch*1k trials: 3.640s curr time: 2023-07-04 16:49:19.319106
# Epoch:  6, Loss: 4.477646, R2: 0.13,  best epoch: 4,  secs per epoch: 5.098 s,  secs epoch*1k trials: 3.426s curr time: 2023-07-04 16:49:23.144498
# Epoch:  7, Loss: 4.450406, R2: 0.13,  best epoch: 5,  secs per epoch: 4.920 s,  secs epoch*1k trials: 3.306s curr time: 2023-07-04 16:49:27.171073
# Epoch:  8, Loss: 4.423236, R2: 0.13,  best epoch: 6,  secs per epoch: 4.906 s,  secs epoch*1k trials: 3.297s curr time: 2023-07-04 16:49:31.997200
# Epoch:  9, Loss: 4.395513, R2: 0.13,  best epoch: 7,  secs per epoch: 4.937 s,  secs epoch*1k trials: 3.318s curr time: 2023-07-04 16:49:37.146977
# Epoch: 10, Loss: 4.368396, R2: 0.13,  best epoch: 8,  secs per epoch: 4.924 s,  secs epoch*1k trials: 3.309s curr time: 2023-07-04 16:49:41.966215
# Final loss: 4.3683959643 , R2: 0.13
# Total time (model/function): (85.156s / 44.315s)
# Time per epoch (model/function): (9.462s/ 4.924s)
# Time per epoch per 1k trials: 3.309s
# Current time: 2023-07-04 16:49:43.350150
#
#
# final refinement step (after shift)...
#
# unfreezing all layers for final refinement
#
# kernels mask None
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 10
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# Epoch:  2, Loss: 4.280509, R2: 0.14,  best epoch: 0,  secs per epoch: 8.340 s,  secs epoch*1k trials: 5.605s curr time: 2023-07-04 16:49:51.693014
# Epoch:  3, Loss: 4.253657, R2: 0.14,  best epoch: 1,  secs per epoch: 6.407 s,  secs epoch*1k trials: 4.306s curr time: 2023-07-04 16:49:56.167051
# Epoch:  4, Loss: 4.226784, R2: 0.14,  best epoch: 2,  secs per epoch: 5.932 s,  secs epoch*1k trials: 3.986s curr time: 2023-07-04 16:50:01.147416
# Epoch:  5, Loss: 4.200719, R2: 0.14,  best epoch: 3,  secs per epoch: 5.947 s,  secs epoch*1k trials: 3.996s curr time: 2023-07-04 16:50:07.139403
# Epoch:  6, Loss: 4.174250, R2: 0.14,  best epoch: 4,  secs per epoch: 5.943 s,  secs epoch*1k trials: 3.994s curr time: 2023-07-04 16:50:13.068723
# Epoch:  7, Loss: 4.148476, R2: 0.14,  best epoch: 5,  secs per epoch: 5.636 s,  secs epoch*1k trials: 3.788s curr time: 2023-07-04 16:50:17.171358
# Epoch:  8, Loss: 4.122921, R2: 0.14,  best epoch: 6,  secs per epoch: 5.421 s,  secs epoch*1k trials: 3.643s curr time: 2023-07-04 16:50:21.296991
# Epoch:  9, Loss: 4.097700, R2: 0.14,  best epoch: 7,  secs per epoch: 5.216 s,  secs epoch*1k trials: 3.505s curr time: 2023-07-04 16:50:25.076880
# Epoch: 10, Loss: 4.072832, R2: 0.14,  best epoch: 8,  secs per epoch: 5.042 s,  secs epoch*1k trials: 3.389s curr time: 2023-07-04 16:50:28.733046
# Final loss: 4.0728322665 , R2: 0.14
# Total time (model/function): (130.539s / 45.383s)
# Time per epoch (model/function): (14.504s/ 5.043s)
# Time per epoch per 1k trials: 3.389s
# Current time: 2023-07-04 16:50:29.810408
# best loss 4.072832266489665
# current r2 values by newly added kernel
# [0.14285607452190807]
# optimizing feature type dinuc
# the optimization of dinucleotide features is skipped...
#
# optimization finished:
# total time: 130.53870725631714s
# Time per epoch (total): 0.045 s

# %%
n_epochs_intercept = 1
n_epochs_kernel = 1
model, best_loss = model.optimize_iterative(train, n_epochs=[n_epochs_intercept] + [n_epochs_kernel] * (n_kernels + 1),
                                            show_logo=False, use_mono=True, use_dinuc=False, dinuc_mode='local',
                                            opt_kernel_shift=[0, 0] + [0] * (n_kernels),
                                            opt_kernel_length=[0, 0] + [0] * (n_kernels),
                                            opt_one_step=True,
                                            shift_max=1, shift_step=1, optimiser=topti.Adam,
                                            skip_kernels=range(2, 500),
                                            n_batches=1, n_rounds=2, num_epochs_shift_factor=1, # log_etas=log_etas, # log_etas=log_etas,
                                            kernels = [0] + [2] + [20] * (n_kernels), r2_per_epoch=True,
                                            exp_max=8,
                                            early_stopping=250, log_each=1, w=20, max_w=20) #  target_dim=train.dataset.signal.shape[1])
# Out:
# [autoreload of mubind.models.models failed: Traceback (most recent call last):
#   File "/home/rio/miniconda3/envs/mubind/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/rio/miniconda3/envs/mubind/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 496, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/rio/miniconda3/envs/mubind/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 393, in update_generic
#     update(a, b)
#   File "/home/rio/miniconda3/envs/mubind/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 361, in update_class
#     update_instances(old, new)
#   File "/home/rio/miniconda3/envs/mubind/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 315, in update_instances
#     refs = gc.get_referrers(old)
# KeyboardInterrupt
# ]
# current kernels
#
# Kernel to optimize 0
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 1
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[280], line 3
#       1 n_epochs_intercept = 1
#       2 n_epochs_kernel = 1
# ----> 3 model, best_loss = model.optimize_iterative(train, n_epochs=[n_epochs_intercept] + [n_epochs_kernel] * (n_kernels + 1),
#       4                                             show_logo=False, use_mono=True, use_dinuc=False, dinuc_mode='local',
#       5                                             opt_kernel_shift=[0, 0] + [0] * (n_kernels),
#       6                                             opt_kernel_length=[0, 0] + [0] * (n_kernels),
#       7                                             opt_one_step=True,
#       8                                             shift_max=1, shift_step=1, optimiser=topti.Adam,
#       9                                             skip_kernels=range(2, 500),
#      10                                             n_batches=1, n_rounds=2, num_epochs_shift_factor=1, # log_etas=log_etas, # log_etas=log_etas,
#      11                                             kernels = [0] + [2] + [20] * (n_kernels), r2_per_epoch=True,
#      12                                             exp_max=8,
#      13                                             early_stopping=250, log_each=1, w=20, max_w=20)
#
# File /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/mubind/models/models.py:940, in Mubind.optimize_iterative(self, train, max_w, n_epochs, early_stopping, log_each, opt_kernel_shift, opt_kernel_length, opt_one_step, expand_length_max, expand_length_step, show_logo, optimiser, seed, init_random, joint_learning, ignore_kernel, lr, weight_decay, stop_at_kernel, dirichlet_regularization, verbose, exp_max, shift_max, shift_step, r2_per_epoch, skip_kernels, **kwargs)
#     937 if verbose != 0:
#     938     print("kernels mask", self.get_ignore_kernel())
# --> 940 self.optimize_simple(
#     941     train,
#     942     next_optimiser,
#     943     num_epochs=n_epochs[i] if isinstance(n_epochs, list) else n_epochs,
#     944     early_stopping=next_early_stopping,
#     945     log_each=log_each,
#     946     dirichlet_regularization=dirichlet_regularization,
#     947     exp_max=exp_max,
#     948     verbose=verbose,
#     949     r2_per_epoch=r2_per_epoch,
#     950     **kwargs,
#     951 )
#     953 # vprint('grad')
#     954 # vprint(model.binding_modes.conv_mono[1].weight.grad)
#     955 # vprint(model.binding_modes.conv_di[1].weight.grad)
#     956 # vprint('')
#     958 self.loss_color += list(np.repeat(colors[i % len(colors)], len(self.loss_history) - len(self.loss_color)))
#
# File /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/mubind/models/models.py:631, in Mubind.optimize_simple(self, dataloader, optimiser, num_epochs, early_stopping, dirichlet_regularization, exp_max, log_each, verbose, r2_per_epoch, **kwargs)
#     628 optimiser.zero_grad(set_to_none=None)
#     630 # outputs, reconstruction = model(inputs)  # Forward pass through the network.
# --> 631 outputs = self.forward(**inputs)  # Forward pass through the network.
#     633 # print(outputs.shape, rounds.shape)
#     634 # print(torch.cat([outputs, rounds], axis=1)[:3])
#     635 # assert False
#     636
#     637 # weight_dist = model.weight_distances_min_k()
#     638 if dirichlet_regularization == 0:
#
# File /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/mubind/models/models.py:255, in Mubind.forward(self, mono, **kwargs)
#     253     return binding_scores
#     254 elif self.datatype == "selex":
# --> 255     return self.graph_module(binding_scores, **kwargs)
#     256 else:
#     257     return None
#
# File ~/miniconda3/envs/mubind/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/mubind/models/models.py:1897, in GraphModule.forward(self, binding_scores, countsum, **kwargs)
#    1893 # conn_spa_T = torch.transpose(C, 0, 1)
#    1894
#    1895 # dynamic
#    1896 if True:
# -> 1897     D = self.log_dynamic
#    1898     D_tril = tspa(a_ind, D, C.shape)  # .requires_grad_(True).cuda()
#    1899     D_triu = tspa(a_ind, -D, C.shape)  # .requires_grad_(True).cuda()
#
# File ~/miniconda3/envs/mubind/lib/python3.10/site-packages/torch/nn/modules/module.py:1207, in Module.__getattr__(self, name)
#    1205     if name in modules:
#    1206         return modules[name]
# -> 1207 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1208     type(self).__name__, name))
#
# AttributeError: 'GraphModule' object has no attribute 'log_dynamic'

# %%
# %lprun -f model.loss_log_dynamic model.optimize_iterative(train, n_epochs=[n_epochs_intercept] + [n_epochs_kernel] * (n_kernels + 1), show_logo=False, use_mono=True, use_dinuc=False, dinuc_mode='local', opt_kernel_shift=[0, 0] + [0] * (n_kernels), opt_kernel_length=[0, 0] + [0] * (n_kernels), opt_one_step=True, shift_max=1, shift_step=1, optimiser=topti.Adam, skip_kernels=range(2, 500), n_batches=1, n_rounds=2, num_epochs_shift_factor=1, kernels = [0] + [2] + [20] * (n_kernels), r2_per_epoch=True, exp_max=8, early_stopping=250, log_each=10, w=20, max_w=20) #  target_dim=train.dataset.signal.shape[1])
# Out:
# current kernels
#
# Kernel to optimize 0
#
# FREEZING KERNELS
# optimizing feature type mono
# setting grad status of kernel (mono, dinuc) at 0 to (1, 0)
# kernels mask None
# optimizer:  Adam
# criterion: PoissonLoss
# # epochs: 5
# early_stopping: 250
# lr= 0.01, weight_decay= 0, dir weight= 0
# *** KeyboardInterrupt exception caught in code being profiled.
# Timer unit: 1e-09 s
#
# Total time: 9.87335 s
# File: /mnt/c/Users/ignacio.ibarra/Dropbox/workspace/theislab/mubind/mubind/models/models.py
# Function: loss_log_dynamic at line 416
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    416                                               def loss_log_dynamic(self):
#    417
#    418        15     121336.0   8089.1      0.0          if not hasattr(self.graph_module, 'conn_sparse'):
#    419                                                       return 0
#    420
#    421        15      31089.0   2072.6      0.0          conn = self.graph_module.conn_sparse
#    422
#    423                                                   # log_dynamic = self.graph_module.D_tril # log_dynamic
#    424                                                   # return 100
#    425
#    426        15   24306563.0 1620437.5      0.2          log_dynamic = self.graph_module.D_tril.coalesce().values() # self.graph_module.D_tril # log_dynamic
#    427
#    428                                                   # return torch.sparse.sum(log_dynamic)
#    429
#    430        15     102234.0   6815.6      0.0          idx = conn.indices()
#    431        15      68638.0   4575.9      0.0          conn_vals = conn.values()
#    432        15    1778897.0 118593.1      0.0          pos = torch.arange(idx.size(1))
#    433
#    434                                                   # prepare combinations based on common indexes
#    435        15   10711118.0 714074.5      0.1          uniq_idx = idx.unique()
#    436        15       8317.0    554.5      0.0          all_combinations = []
#    437     14243   36229010.0   2543.6      0.4          for u_idx in uniq_idx:
#    438                                                       # at least one common index has to be present in the position retrieved
#    439     14243 7291107137.0 511908.1     73.8              sub_pos = pos[(idx[0] == u_idx) | (idx[1] == u_idx)]
#    440     14242 2060267831.0 144661.4     20.9              c = torch.combinations(sub_pos, r=2)
#    441     14242   22301195.0   1565.9      0.2              all_combinations.append(c)
#    442        14   87064989.0 6218927.8      0.9          all_pos = torch.cat(all_combinations)
#    443        14  106980547.0 7641467.6      1.1          pairs = idx[:, all_pos].reshape(all_pos.shape[0], 4)
#    444
#    445                                                   # pairs = idx[all_pos].reshape(all_pos.shape[0], 4)
#    446        14    1530550.0 109325.0      0.0          mask1 = (pairs[:, 0] == pairs[:, 2]) | (pairs[:, 1] == pairs[:, 3])
#    447        14     879297.0  62806.9      0.0          mask2 = (pairs[:, 0] != pairs[:, 1]) & (pairs[:, 2] != pairs[:, 3])
#    448        14     775942.0  55424.4      0.0          mask3 = ~((pairs[:, 0] == pairs[:, 2]) & (pairs[:, 1] != pairs[:, 3]))
#    449
#    450        14   77493951.0 5535282.2      0.8          pairs = pairs[mask1 & mask2 & mask3]
#    451
#    452        14   58362514.0 4168751.0      0.6          all_pos = all_pos[mask1 & mask2 & mask3]
#    453
#    454        14   24938218.0 1781301.3      0.3          a = log_dynamic[all_pos[:, 0]]
#    455        14   20966658.0 1497618.4      0.2          b = log_dynamic[all_pos[:, 1]]
#    456        14    1268841.0  90631.5      0.0          w_err = (a - b) ** 2
#    457        14   44312126.0 3165151.9      0.4          conn_weight = conn_vals[all_pos[:, 0]] * conn_vals[all_pos[:, 1]]
#    458        14     251010.0  17929.3      0.0          score = w_err * conn_weight
#    459
#    460        14    1480999.0 105785.6      0.0          w_err = score.sum() / idx.shape[0]
#    461                                                   # return sum(w_err + torch.rand(1, device=self.device))
#    462        14       8238.0    588.4      0.0          return w_err

# %%
# Out:
# tensor(indices=tensor([[  0,   0,   0,  ..., 999, 999, 999],
#                        [196, 212, 218,  ..., 938, 943, 954]]),
#        values=tensor([0.9543, 0.7219, 0.5416,  ..., 0.3355, 0.7990, 0.7495]),
#        device='cuda:0', size=(1000, 1000), nnz=27116, layout=torch.sparse_coo,
#        grad_fn=<SparseCooTensorWithDimsAndTensorsBackward0>)

# %%
mb.pl.set_rcParams({'figure.figsize': [12, 3], 'figure.dpi': 110})
for optimize_log_dynamic in model_by_logdynamic:
    model = model_by_logdynamic[optimize_log_dynamic]
    print(optimize_log_dynamic)
    plt.subplot(1, 4, 1)
    plt.plot(model.loss_history_log_dynamic)
    plt.ylabel('log dynamic loss')
    plt.subplot(1, 4, 2)
    plt.plot(model.loss_history)
    plt.ylabel('overall loss')
    plt.subplot(1, 4, 3)
    plt.plot(model.loss_history_sym_weights)
    plt.ylabel('similar weights loss')
    plt.show()
# Out:
# True
# False

# %%
n_cols = int(len(model.binding_modes.conv_mono) ** .5) + 1
for optimize_log_dynamic in model_by_logdynamic:
    print(optimize_log_dynamic)
    model = model_by_logdynamic[optimize_log_dynamic]
    from matplotlib import rcParams
    rcParams['figure.figsize'] = 20, 5
    rcParams['figure.dpi'] = 100
    mb.pl.logo(model, n_cols=n_cols, show=True, n_rows=n_cols)
    plt.show()
# Out:
# True
# True
# 3
# order None
# 0 out of 5...
# done with mono
# False
# True
# 3
# order None
# 0 out of 5...
# done with mono

# %%
r2_net = None
for optimize_log_dynamic in model_by_logdynamic:
    print(optimize_log_dynamic)
    model = model_by_logdynamic[optimize_log_dynamic]
    # contributions per newly added kernel
    import seaborn as sns
    if len(model.best_r2_by_new_filter) != 0:
        r2 = pd.DataFrame(model.best_r2_by_new_filter, columns=['r2']).reset_index()
        r2['opt_log_dynamic'] = optimize_log_dynamic
        r2_net = r2 if r2_net is None else r2_net.append(r2)

rcParams['figure.figsize'] = 5, 5
rcParams['figure.dpi'] = 80
sns.barplot(data=r2_net, x='index', y='r2', hue='opt_log_dynamic')
plt.show()
# Out:
# True
# False

# %%
gm = model.graph_module
D_triu = -gm.D_tril # opposite sign
D_all = gm.D_tril + t(D_triu, 0, 1)
D_all.to_dense()
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000, -0.3540,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.3540,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0', grad_fn=<ToDenseBackward0>)

# %%
sns.heatmap(D_all.to_dense()[:39,:39].detach().cpu(), cmap='RdBu_r')
# Out:
# <AxesSubplot: >

# %%
torch.set_printoptions(precision=2)
dynamic_score = D.to_dense().detach().cpu().sum(axis=0)
# Out:
# Parameter containing:
# tensor([0.9343, 0.7233, 0.5287,  ..., 0.3554, 0.7790, 0.7562], device='cuda:0',
#        requires_grad=True)

# %%
# dyn_score
dynamic_score = dynamic_score
dynamic_score = (dynamic_score - dynamic_score.min()) / (dynamic_score.max() - dynamic_score.min())
ad.obs['dynamic_score'] = dynamic_score

# %%
ad.obs['dynamic_score_cluster'] = np.where(dynamic_score > dynamic_score.mean(), 'dynamic', 'static')
z1 = np.where(((dynamic_score - dynamic_score.mean()) / dynamic_score.std()) > dynamic_score.quantile(.66), 'dynamic', 'static')
z2 = np.where(((dynamic_score - dynamic_score.mean()) / dynamic_score.std()) > dynamic_score.quantile(.95), 'dynamic', 'static')

ad.obs['dynamic_score_z1'] = z1
ad.obs['dynamic_score_z2'] = z2

#  ad.obs['dynamic_score_cluster'] = np.where(dynamic_score > .5, , 0)
sns.displot(dynamic_score, bins=15)
plt.xlabel('dynamic score (normalized)')
# Out:
# Text(0.5, 7.555555555555548, 'dynamic score (normalized)')

# %%
# contributions per newly added kernel
rcParams['figure.figsize'] = 5, 5
rcParams['figure.dpi'] = 70
sc.pl.umap(ad, color=['dynamic_score'], cmap='RdBu_r', sort_order=True)
sc.pl.umap(ad, color=['dynamic_score_z1'], cmap='RdBu_r', sort_order=True)

# %%
ad.obs['dynamic_score_z1']
# Out:
# index
# cellranger-arc201_count_dae7bef086560538e47878293f38b2c6#AGGGCTACACAACCTA-1                                                                                           dynamic
# cellranger-arc201_count_dae7bef086560538e47878293f38b2c6#CGCATTTGTTTGGGTA-1                                                                                            static
# cellranger-arc201_count_dae7bef086560538e47878293f38b2c6#CAGGTTTAGGCTAATC-1                                                                                           dynamic
# cellranger-arc201_count_dae7bef086560538e47878293f38b2c6#GTCATCCTCAAGCGCC-1                                                                                           dynamic
# cellranger-arc201_count_dae7bef086560538e47878293f38b2c6#AGTCAGGCAGCACGTT-1                                                                                            static
#                                                                                                                                                                        ...
# cellranger-arc201_count_45160_GBM_RNA12936177_and_45161_GBM_RNA12936177_and_45166_GBM_RNA12930346_and_45171_GBM_RNA12930346_GRCh38-2020-A-2_0_0#CGATTATCACGGTTTA-1     static
# cellranger-arc201_count_45160_GBM_RNA12936177_and_45161_GBM_RNA12936177_and_45166_GBM_RNA12930346_and_45171_GBM_RNA12930346_GRCh38-2020-A-2_0_0#GGTTCCCGTTTGCGAA-1     static
# cellranger-arc201_count_45160_GBM_RNA12936177_and_45161_GBM_RNA12936177_and_45166_GBM_RNA12930346_and_45171_GBM_RNA12930346_GRCh38-2020-A-2_0_0#GTAAGCTTCCTAATAG-1     static
# cellranger-arc201_count_590b26c0e38e6de507f3b1bfc49bc3ef#TTCACTGTCCCAGTAG-1                                                                                           dynamic
# cellranger-arc201_count_590b26c0e38e6de507f3b1bfc49bc3ef#ATGGCTTAGAGAGCCG-1                                                                                            static
# Name: dynamic_score_z1, Length: 850, dtype: category
# Categories (2, object): ['dynamic', 'static']

# %%
# contributions per newly added kernel
rcParams['figure.figsize'] = 2, 3
rcParams['figure.dpi'] = 120

sc.tl.embedding_density(ad, basis='umap', groupby='dynamic_score_z1')
sc.pl.embedding_density(ad, basis='umap', key='umap_density_dynamic_score_z1', group='dynamic') # basis='umap', groupby='dynamic_score_cluster')
sc.tl.embedding_density(ad, basis='umap', groupby='dynamic_score_z2')
sc.pl.embedding_density(ad, basis='umap', key='umap_density_dynamic_score_z2', group='dynamic') # basis='umap', groupby='dynamic_score_cluster')

# %%
sc.set_figure_params()

# %%
mb.pl.set_rcParams({'figure.figsize': [5, 5], 'figure.dpi': 60})
mb.pl.kmer_enrichment(model, train, log_scale=False, style='scatter', ylab='t1', xlab='p1', k=6)
# Out:
# {'r2_counts': 0.12547228137146793,
#  'r2_foldchange': -0.03025616672286513,
#  'r2_enr': -0.0759225318704746,
#  'r2_fc': 0.010970165687432873,
#  'pearson_foldchange': 0.104738558742389}

# %%
umap = ad.obsm['X_umap'].copy()
umap = np.sort(umap, 0)

x = umap[:,0]
y = umap[:,1]
X, Y = np.meshgrid(x, y)

n_points = x.shape[0]
# x-component to the right
u = np.ones((n_points, n_points))
# y-component zero
v = np.zeros((n_points, n_points))

# %%
D.shape
# Out:
# torch.Size([850, 850])

# %%
import scvelo as scv

# %%
ad.shape
# Out:
# (850, 1263)

# %%
log_act = torch.exp(torch.stack(list(model.activities.log_activities), dim=1)).squeeze(0).T
log_act.shape
# Out:
# torch.Size([850, 52])

# %%
train.dataset.mononuc.shape
# Out:
# (1263, 4, 500)

# %%
pred = []
for i, batch in enumerate(train):
    # Get a batch and potentially send it to GPU memory.
    mononuc = batch["mononuc"].to(device)
    # print(i, mononuc.shape)
    b = batch["batch"].to(device) if "batch" in batch else None
    rounds = batch["rounds"].to(device) if "rounds" in batch else None
    countsum = batch["countsum"].to(device) if "countsum" in batch else None
    seq = batch["seq"] if "seq" in batch else None
    residues = batch["residues"].to(device) if "residues" in batch else None
    if residues is not None and train.dataset.store_rev:
        mononuc_rev = batch["mononuc_rev"].to(device)
        inputs = {"mono": mononuc, "mono_rev": mononuc_rev, "batch": b, "countsum": countsum,
                  "residues": residues}
    elif residues is not None:
        inputs = {"mono": mononuc, "batch": b, "countsum": countsum, "residues": residues}
    elif train.dataset.store_rev:
        mononuc_rev = batch["mononuc_rev"].to(device)
        inputs = {"mono": mononuc, "mono_rev": mononuc_rev, "batch": b, "countsum": countsum}
    else:
        inputs = {"mono": mononuc, "batch": b, "countsum": countsum}

    inputs['scale_countsum'] = model.datatype == 'selex'
    output = model(**inputs, use_conn=False)

    output = output.cpu().detach().numpy()
    print('here...')
    print(output.shape)

    print(output.sum())
    pred.append(output)

pred = np.concatenate(pred).T
ad.layers['velocity'] = pred
ad.layers['counts'] = ad.X
# Out:
# here...
# (512, 850)
# 18259.0
# here...
# (512, 850)
# 14538.001
# here...
# (239, 850)
# 4946.9995

# %%
ad.layers['counts']
# Out:
# <850x1263 sparse matrix of type '<class 'numpy.float32'>'
# 	with 20642 stored elements in Compressed Sparse Row format>

# %%
plt.hist(model.selex_module.conn_sparse.values().detach().cpu().numpy())
# Out:
# (array([3236., 8858., 4804., 1680.,  860.,  540.,  338.,  294.,  186.,
#         1856.]),
#  array([2.80259693e-45, 1.00000001e-01, 2.00000003e-01, 3.00000012e-01,
#         4.00000006e-01, 5.00000000e-01, 6.00000024e-01, 6.99999988e-01,
#         8.00000012e-01, 8.99999976e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
pred.shape
# Out:
# (850, 1263)

# %%
ad.shape
# Out:
# (850, 1263)

# %%
sc.pp.neighbors(ad)

# %%
# ad.layers['log_act'] = dyn_umap.X
# ad.layers['counts'] = ad.X
scv.tl.velocity_graph(ad, vkey='velocity', xkey='counts')
# Out:
# computing velocity graph (using 1/16 cores)
#   0%|          | 0/850 [00:00<?, ?cells/s]
#     finished (0:00:01) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
ad.obs['site_id'].value_counts()
# Out:
# AT9-BRA-4-FO-4     82
# AT9-BRA-4-FO-3     53
# AT6-BRA-3-FO-4     51
# AT5-BRA-5-FO-3     50
# AT9-BRA-4-FO-2     44
# AT3-BRA-5-FO-3     38
# AT6-BRA-3-FO-3     37
# AT4-BRA-5-FO-3     36
# AT4-BRA-5-FO-4     36
# AT10-BRA-5-FO-1    35
# AT7-BRA-3-FO-3     34
# AT10-BRA-5-FO-4    34
# AT4-BRA-5-FO-2     31
# AT4-BRA-5-FO-1     31
# AT3-BRA-5-FO-1     27
# AT10-BRA-5-FO-2    23
# AT6-BRA-3-FO-1     22
# AT5-BRA-5-FO-2     22
# AT5-BRA-5-FO-1     21
# AT5-BRA-5-FO-4     19
# AT7-BRA-3-FO-1     19
# AT9-BRA-4-FO-1     19
# AT10-BRA-5-FO-3    19
# AT6-BRA-3-FO-2     18
# AT3-BRA-5-FO-4     18
# AT3-BRA-5-FO-2     17
# AT7-BRA-3-FO-4     12
# AT7-BRA-3-FO-2      2
# Name: site_id, dtype: int64

# %%
scv.pl.velocity_embedding_stream(ad, color='site_id') #  X_grid='X_umap', V=V)

# %%
ad.shape
# Out:
# (850, 1263)

# %%
act = torch.stack(list(model.activities.log_activities), dim=1).squeeze(0).T
# log_act = torch.exp(torch.stack(list(model.activities.log_activities), dim=1)).squeeze(0).T
# log_act

# %%
vmax = act.abs().max()
sns.clustermap(act.detach().cpu().numpy(), cmap='RdBu_r', vmin=-vmax, vmax=vmax, yticklabels=False, figsize=[5, 5,])

# %%
scv.pl.velocity_embedding_stream(ad, color='site_id') #  X_grid='X_umap', V=V)

# %%
log_act.shape
# Out:
# torch.Size([850, 52])

# %%
ad.shape
# Out:
# (850, 1263)

# %%
log_act = torch.stack(list(model.activities.log_activities), dim=1).squeeze(0).T
log_act = pd.DataFrame(log_act.detach().cpu().numpy())
# log_act.columns = anno['Seed_motif'][2]
log_act.columns = ['intercept', 'dinuc_bias'] + list(anno.head(log_act.shape[1] - 2)['Seed_motif'].values)

log_act.index = ad.obs_names
ad.obsm['mubind_activities'] = log_act
for c in ad.obsm['mubind_activities']:
    ad.obs[c] = ad.obsm['mubind_activities'][c]

# %%
delta = (log_act.max(axis=0) - log_act.min(axis=0))
var = log_act.var(axis=0)
plt.scatter(delta, var)
plt.xlabel('min-max range')
plt.ylabel('variability')
plt.title('TF modules (by score)')
# Out:
# Text(0.5, 1.0, 'TF modules (by score)')

# %%
scores = pd.concat([delta, var], axis=1)
scores['combined'] = scores.sum(axis=1)
scores.sort_values('combined', ascending=False)
scores['idx'] = np.arange(scores.shape[0])

# %%
scores
# Out:
#                               0             1  combined  idx
# intercept              0.000159  7.462903e-11  0.000159    0
# dinuc_bias             0.048249  7.350048e-06  0.048257    1
# AHR_HUMAN.H11MO.0.B    1.069109  3.602836e-03  1.072712    2
# AIRE_HUMAN.H11MO.0.C   1.107797  1.316763e-02  1.120964    3
# ATF3_MOUSE.H11MO.0.A   0.366860  9.814808e-04  0.367841    4
# BACH1_HUMAN.H11MO.0.A  1.191674  8.274385e-03  1.199948    5
# Arid5a_MA0602.1        1.652855  1.302148e-02  1.665876    6
# ARI5B_HUMAN.H11MO.0.C  0.617079  4.546184e-03  0.621625    7
# BATF3_HUMAN.H11MO.0.B  1.677625  1.511458e-02  1.692739    8
# BCL6B_C2H2_1           1.828983  3.907131e-02  1.868055    9
# BCL6_HUMAN.H11MO.0.A   0.675427  4.397765e-03  0.679824   10
# CEBPA_HUMAN.H11MO.0.A  0.702849  2.693473e-03  0.705542   11
# CENPB_CENPB_1          1.412298  1.676722e-02  1.429065   12
# CPEB1_RRM_1            0.823620  2.017729e-03  0.825638   13
# ATF1_HUMAN.H11MO.0.B   0.631095  1.311143e-03  0.632406   14
# ATF7_MA0834.1          1.156501  5.930793e-03  1.162432   15
# ATF4_HUMAN.H11MO.0.A   0.938031  3.258115e-03  0.941289   16
# ATF6A_HUMAN.H11MO.0.B  1.710106  1.469609e-02  1.724802   17
# CTCFL_HUMAN.H11MO.0.A  2.921442  8.409216e-02  3.005534   18
# CUX1_CUT_3             0.509059  1.107607e-03  0.510167   19
# CUX1_CUT_2             1.599578  2.815226e-02  1.627730   20
# CUX1_CUT_1             1.406518  1.652175e-02  1.423040   21
# CUX2_MOUSE.H11MO.0.C   0.693462  1.787528e-03  0.695250   22
# Ddit3+Cebpa_MA0019.1   0.723016  2.598335e-03  0.725614   23
# DMRT1_MOUSE.H11MO.0.C  1.507187  1.208589e-02  1.519273   24
# DMRT3_MA0610.1         0.890272  1.815785e-03  0.892088   25
# E2F1_E2F_1             1.132884  8.655602e-03  1.141540   26
# E2F1_HUMAN.H11MO.0.A   2.792345  4.232803e-02  2.834673   27
# E2F7_E2F_1             1.030785  1.613791e-02  1.046923   28
# E2F2_HUMAN.H11MO.0.B   1.461532  5.830799e-03  1.467363   29
# COE1_HUMAN.H11MO.0.A   1.516562  2.339451e-02  1.539957   30
# FIGLA_MA0820.1         0.460598  7.889188e-04  0.461387   31
# ARNTL_bHLH_1           0.893576  4.531570e-03  0.898107   32
# CLOCK_HUMAN.H11MO.0.C  0.938773  3.196619e-03  0.941970   33
# ATOH1_HUMAN.H11MO.0.B  0.667179  2.338921e-03  0.669518   34
# ASCL1_HUMAN.H11MO.0.A  1.621606  2.023261e-02  1.641838   35
# Atoh1.mouse_bHLH_1     0.720505  8.873599e-04  0.721392   36
# EGR1_C2H2_1            2.250348  3.741191e-02  2.287760   37
# EHF_ETS_1              0.817200  3.164324e-03  0.820364   38
# EHF_HUMAN.H11MO.0.B    0.694546  5.522112e-03  0.700068   39
# EVI1_HUMAN.H11MO.0.B   2.455449  2.516950e-02  2.480618   40
# EWSR1-FLI1_MA0149.1    2.176892  7.016674e-02  2.247059   41
# FEZF1_HUMAN.H11MO.0.C  0.779594  2.754060e-03  0.782348   42
# FOXH1_HUMAN.H11MO.0.A  0.226067  3.726752e-04  0.226440   43
# FOXO1_forkhead_2       2.315171  2.957590e-02  2.344747   44
# FOXI1_forkhead_2       1.779981  4.346044e-02  1.823441   45
# ANDR_HUMAN.H11MO.0.A   1.890848  3.927658e-02  1.930125   46
# FOXC1_forkhead_1       1.982368  3.346487e-02  2.015832   47
# FOXB1_forkhead_2       2.960886  8.264053e-02  3.043527   48
# FOXO1_forkhead_3       1.080965  6.037583e-03  1.087002   49
# FOXG1_forkhead_2       1.276201  1.141332e-02  1.287614   50
# FOXB1_forkhead_1       0.819015  5.456606e-03  0.824471   51

# %%
gene_query = 'CTCF'
names_query = anno[anno['Cluster_ID'].isin(set(clu[clu['Motif'].str.contains(gene_query)]['Cluster_ID'].values))]['Seed_motif'].values
names_query
# Out:
# array(['CTCFL_HUMAN.H11MO.0.A'], dtype=object)

# %%
# top_idx = scores.sort_values('combined', ascending=False).head(5).index
# idx_mb_model = scores.sort_values('combined', ascending=False).head(5)['idx'].values
top_idx = scores.head()[2:8].index
idx_mb_model = scores.head()['idx'].values[2:8]

# %%
idx_mb_model
# Out:
# array([2, 3, 4])

# %%
top_idx, idx_mb_model
# Out:
# (Index(['AHR_HUMAN.H11MO.0.B', 'AIRE_HUMAN.H11MO.0.C', 'ATF3_MOUSE.H11MO.0.A'], dtype='object'),
#  array([2, 3, 4]))

# %%
# top_idx = [0, 1, 2, 3]

# %%
mb.pl.set_rcParams({'figure.figsize': [20, 3], 'figure.dpi': 90})
for k in top_idx:
    print(k)
mb.pl.logo_mono(weights_list=[pwms_by_name[k] for k in top_idx], n_cols=4, n_rows=2)
# Out:
# AHR_HUMAN.H11MO.0.B
# AIRE_HUMAN.H11MO.0.C
# ATF3_MOUSE.H11MO.0.A
# 0 0 (4, 9)
# 1 1 (4, 18)
# 2 2 (4, 9)

# %%
mb.pl.logo_mono(model, subset=[idx - 1 for idx in idx_mb_model], n_cols=4, n_rows=2)
# Out:
# 0 1 (4, 2)
# 1 2 (4, 9)
# 2 3 (4, 18)

# %%
mb.pl.set_rcParams({'figure.figsize': [6, 3], 'figure.dpi': 90})
sc.pl.umap(ad, color=names_query, cmap='RdBu_r')

# %%
for k in top_idx:
    print(k)


# model
mb.pl.logo(model, subset=[idx - 1 for idx in idx_mb_model], n_cols=4, n_rows=2)
# Out:
# AHR_HUMAN.H11MO.0.B
# AIRE_HUMAN.H11MO.0.C
# ATF3_MOUSE.H11MO.0.A
# 0 1 (4, 2)
# 1 2 (4, 9)
# 2 3 (4, 18)

# %%
pwms_show = [np.log2((pwms_by_name[k] + 1e-3) / (0.25) + 1e-3) for k in pwms_by_name][:20]

# %%
for i, pwm in enumerate(pwms_show):
    pwm[pwm < 0] = 0

# %%
# original pwms
mb.pl.set_rcParams({'figure.figsize': [9, 12], 'figure.dpi': 25})
mb.pl.logo_mono(weights_list=pwms_show,
                n_cols=3, n_rows=6)
# Out:
# 0 0 (4, 9)
# 1 1 (4, 18)
# 2 2 (4, 9)
# 3 3 (4, 13)
# 4 4 (4, 14)
# 5 5 (4, 13)
# 6 6 (4, 17)
# 7 7 (4, 17)
# 8 8 (4, 13)
# 9 9 (4, 12)
# 10 10 (4, 15)
# 11 11 (4, 8)
# 12 12 (4, 11)
# 13 13 (4, 14)
# 14 14 (4, 12)
# 15 15 (4, 12)
# 16 16 (4, 17)
# 17 17 (4, 10)

# %%
mb.pl.logo_mono(weights_list=[np.log2((pwms_by_name[k] + .1) / (0.25 + .1)) for k in top_idx], n_cols=4, n_rows=3)
# Out:
# 0 0 (4, 9)
# 1 1 (4, 18)
# 2 2 (4, 9)

# %%
sc.pl.umap(ad, color=top_idx, cmap='RdBu_r')
